# %% [markdown]
# # Position and rotation estimation with pooling layers and RGB images
# ## Using rotations defined by RGB values

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
import cv2
import random
import math

import tensorflow as tf
tf.get_logger().setLevel('ERROR')
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow.keras.backend as K
from tensorflow.keras import Input
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, LeakyReLU

# %% [markdown]
# # Preparing data

# %%
DATADIR = "dataset_generator/images/pose5000/"
JSON_file_name = "data.txt"
IMAGES = 5_000
OG_IMG_SIZE = 800
IMG_SIZE = 150

# %%
data_json = []
for line in open(DATADIR + JSON_file_name, 'r'):
    data_json.append(json.loads(line))
    
dataset = [] # [x, y]

for img in os.listdir(DATADIR):
    if(img.endswith(".jpg")):
        img_array = cv2.imread(os.path.join(DATADIR, img))
        img_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))

        img_index = int(img.strip(".jpg"))
        for label in data_json:
            if(label['index'] == img_index):
                choosen_label = {'bx': label['bx'], 
                                 'by': label['by'], 
                                 'bw': label['bw'], 
                                 'bh': label['bh'], 
                                 'posX': label['posX'], 
                                 'posY': label['posY'], 
                                 'posZ': label['posZ'],
                                 'rx': label['rx'],
                                 'gx': label['gx'],
                                 'bxx': label['bxx'],
                                 'ry': label['ry'],
                                 'gy': label['gy'],
                                 'byy': label['byy'],
                                'rotX': label['rotX'],
                                'rotY': label['rotY']}
                
                xy = [img_array, choosen_label]
                dataset.append(xy)
                
        if(len(dataset)%500 ==0):
            print(f"{len(dataset)} images loaded")
        
        if(len(dataset) >= IMAGES):
            print("All images loaded")
            break
            
IMAGES = len(dataset)
print(f"{IMAGES} in total")
# Out:
# 500 images loaded
# 1000 images loaded
# 1500 images loaded
# 2000 images loaded
# 2500 images loaded
# 3000 images loaded
# 3500 images loaded
# 4000 images loaded
# 4500 images loaded
# 5000 images loaded
# All images loaded
# 5000 in total

# %% [markdown]
# # Creating training dataset

# %%
X = []
y = []

shuffled_indices = random.sample(range(0, IMAGES), IMAGES)

for i in shuffled_indices:
    
    pixels = dataset[i][0]
    pixels = pixels.astype('uint8')
    X.append(pixels)
    
    y_labels = [dataset[i][1]['bx'], 
                dataset[i][1]['by'], 
                dataset[i][1]['bw'], 
                dataset[i][1]['bh'], 
                dataset[i][1]['posX'], 
                dataset[i][1]['posY'], 
                dataset[i][1]['posZ'],
                dataset[i][1]['rx'],
                dataset[i][1]['gx'],
                dataset[i][1]['bxx'],
                dataset[i][1]['ry'],
                dataset[i][1]['gy'],
                dataset[i][1]['byy'],
               dataset[i][1]['rotX'],
               dataset[i][1]['rotY']]
    
    y.append(y_labels)

# Global Standardization
X = (np.array(X).reshape(IMAGES, IMG_SIZE, IMG_SIZE, 3) - np.mean(X)) / np.std(X)
    
for index, ya in enumerate(y):
    y[index] = np.array([ya[0]/100, 
                         ya[1]/100, 
                         ya[2]/100, 
                         ya[3]/100, 
                         ya[4]/10, 
                         ya[5]/10, 
                         ya[6]/10, 
                         ya[7]/255,
                         ya[8]/255,
                         ya[9]/255,
                         ya[10]/255,
                         ya[11]/255,
                         ya[12]/255])
    
y = np.array(y)

print(f"X shape: {X.shape}\ny shape: {y.shape}")
# Out:
# X shape: (5000, 150, 150, 3)
# y shape: (5000, 13)

# %%
def RGBToAngle(rgb):
    angle = math.atan2(math.sqrt(3) * (rgb[1] - rgb[2]), 2 * rgb[0] - rgb[1] - rgb[2])
    if(angle < 0):
        angle += math.pi
    
    return math.degrees(angle)

# %%
random_index = random.randrange(IMAGES)
fig, axs = plt.subplots(ncols = 3, figsize = (15, 15))

axs[0].imshow(X[random_index][:, :, 0], cmap="Reds")
axs[1].imshow(X[random_index][:, :, 1], cmap="Greens")
axs[2].imshow(X[random_index][:, :, 2], cmap="Blues")

title = "Labels: \n\
(bx, by, bw, bh): {frameLabels}\n\
(posX, posY, posZ): {positionLabels}\n\
(rotX): {rx:.2f}, {gx:.2f}, {bx:.2f} ({xDegrees1} degrees)\n\
(rotY): {ry:.2f}, {gy:.2f}, {by:.2f} ({yDegrees1} degrees)\n".format(frameLabels = y[random_index][:4],
                              positionLabels = y[random_index][4:7],
                              rx = y[random_index][7],
                              gx = y[random_index][8],
                              bx =y[random_index][9],
                              ry = y[random_index][10],
                              gy = y[random_index][11],
                              by = y[random_index][12],
                              xDegrees1 = int(RGBToAngle(y[random_index][7:10])),
                              yDegrees1 = int(RGBToAngle(y[random_index][10:13])))

axs[1].set_title(title)

plt.show()

# %% [markdown]
# # Model

# %% [markdown]
# ### Custom accuracy metric

# %%
from tensorflow.math import add, subtract, multiply, divide, sqrt, atan2

def position_error_x(y_true, y_pred):
    error_sum = 0
    samples = len(y_true)
    for i in range(samples):
        error_sum += abs(y_true[i][0] - y_pred[i][0])
    return (error_sum * 10)/samples

def position_error_y(y_true, y_pred):
    error_sum = 0
    for i in range(len(y_true)):
        error_sum += abs(y_true[i][1] - y_pred[i][1])
    return (error_sum * 10)/len(y_true)

def position_error_z(y_true, y_pred):
    error_sum = 0
    for i in range(len(y_true)):
        error_sum += abs(y_true[i][2] - y_pred[i][2])
    return (error_sum * 10)/len(y_true)

def acc_20(y_true, y_pred):
    count = 0
    for i in range(len(y_true)):
        angle_true = RGBToAngle(y_true[i])
        angle_pred = RGBToAngle(y_pred[i])
        
        if(abs(angle_true - angle_pred) < 20):
            count += 1
    return count / len(y_true)

def acc_15(y_true, y_pred):
    count = 0
    for i in range(len(y_true)):
        angle_true = RGBToAngle(y_true[i])
        angle_pred = RGBToAngle(y_pred[i])
        
        if(abs(angle_true - angle_pred) < 15):
            count += 1
    return count / len(y_true)

def acc_10(y_true, y_pred):
    count = 0
    for i in range(len(y_true)):
        angle_true = RGBToAngle(y_true[i])
        angle_pred = RGBToAngle(y_pred[i])
        
        if(abs(angle_true - angle_pred) < 10):
            count += 1
    return count / len(y_true)

def acc_5(y_true, y_pred):
    count = 0
    for i in range(len(y_true)):
        angle_true = RGBToAngle(y_true[i])
        angle_pred = RGBToAngle(y_pred[i])
        
        if(abs(angle_true - angle_pred) < 5):
            count += 1
    return count / len(y_true)

# %%
inputs = Input(name = "Inputs",
              shape = (IMG_SIZE, IMG_SIZE, 3))

# Main Stream
positionStream = Conv2D(name = "ps_conv_0",
                   filters = 16,
                   kernel_size = 3,
                   strides = 1,
                   padding = "valid",
                   kernel_initializer=tf.keras.initializers.GlorotUniform())(inputs)

positionStream = LeakyReLU()(positionStream)

positionStream = Conv2D(name = "ps_conv_1",
                   filters = 32,
                   kernel_size = 3,
                   strides = 1,
                   padding = "valid",
                   kernel_initializer=tf.keras.initializers.GlorotUniform())(positionStream)

positionStream = LeakyReLU()(positionStream)

positionStream = MaxPooling2D(name="ps_maxpooling_1", 
                          pool_size = (2, 2), 
                          strides = 2)(positionStream)

positionStream = Conv2D(name = "ps_conv_2",
                   filters = 32,
                   kernel_size = 3,
                   strides = 1,
                   padding = "valid",
                   kernel_initializer=tf.keras.initializers.GlorotUniform())(positionStream)

positionStream = LeakyReLU()(positionStream)

positionStream = MaxPooling2D(name="ps_maxpooling_2", 
                          pool_size = (2, 2), 
                          strides = 2)(positionStream)

# ROTATION START

rotationStream = Conv2D(name = "rs_conv_1",
                   filters = 64,
                   kernel_size = 3,
                   strides = 1,
                   padding = "same",
                   kernel_initializer=tf.keras.initializers.GlorotUniform())(positionStream)

rotationStream = LeakyReLU()(rotationStream)

rotationStream = MaxPooling2D(name="rs_maxpooling_1", 
                          pool_size = (2, 2), 
                          strides = 2)(rotationStream)

rotationStream = Conv2D(name = "rs_conv_2",
                   filters = 64,
                   kernel_size = 3,
                   strides = 1,
                   padding = "same",
                   kernel_initializer=tf.keras.initializers.GlorotUniform())(rotationStream)

rotationStream = LeakyReLU()(rotationStream)

rotationStream = MaxPooling2D(name="rs_maxpooling_2", 
                          pool_size = (2, 2), 
                          strides = 2)(rotationStream)

rotationStream = Flatten()(rotationStream)

rotationStream = Dense(20, activation = "relu")(rotationStream)
rotationStream = Dense(20, activation = "relu")(rotationStream)

rotationStream = Dense(3, name = "rotationOutput")(rotationStream)

# ROTATION END

positionStream = Conv2D(name = "ps_conv_3",
                   filters = 32,
                   kernel_size = 3,
                   strides = 1,
                   padding = "valid",
                   kernel_initializer=tf.keras.initializers.GlorotUniform())(positionStream)

positionStream = LeakyReLU()(positionStream)

positionStream = MaxPooling2D(name="ps_maxpooling_3", 
                          pool_size = (2, 2), 
                          strides = 2)(positionStream)

positionStream = Conv2D(name = "ps_conv_4",
                   filters = 32,
                   kernel_size = 3,
                   strides = 1,
                   padding = "valid",
                   kernel_initializer=tf.keras.initializers.GlorotUniform())(positionStream)

positionStream = LeakyReLU()(positionStream)

positionStream = Flatten()(positionStream)

positionStream = Dense(20, activation = "relu")(positionStream)
positionStream = Dense(20, activation = "relu")(positionStream)

positionStreamOutput = Dense(3, name = "positionOutput")(positionStream)
frameStreamOutput = Dense(4, name = "frameOutput")(positionStream)

model = keras.Model(inputs,[positionStreamOutput, rotationStream, frameStreamOutput], name = "Model")

model_optimizer = tf.keras.optimizers.Adam(
    learning_rate=0.001,
    beta_1=0.95,
    amsgrad=True)

model.compile(optimizer = model_optimizer,
             loss = {"positionOutput": tf.keras.losses.MeanSquaredError(), 
                     "rotationOutput": tf.keras.losses.MeanSquaredError(), 
                     "frameOutput": tf.keras.losses.MeanSquaredError()},
              
             metrics = {"positionOutput": [position_error_x, 
                                           position_error_y, 
                                           position_error_z], 
                        "rotationOutput": [acc_20, 
                                           acc_15, 
                                           acc_10, 
                                           acc_5]},
             run_eagerly=True)

model.summary()
keras.utils.plot_model(model, "model.png", show_shapes=True)
# Out:
# Model: "Model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Inputs (InputLayer)             [(None, 150, 150, 3) 0
# __________________________________________________________________________________________________
# ps_conv_0 (Conv2D)              (None, 148, 148, 16) 448         Inputs[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_161 (LeakyReLU)     (None, 148, 148, 16) 0           ps_conv_0[0][0]
# __________________________________________________________________________________________________
# ps_conv_1 (Conv2D)              (None, 146, 146, 32) 4640        leaky_re_lu_161[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_162 (LeakyReLU)     (None, 146, 146, 32) 0           ps_conv_1[0][0]
# __________________________________________________________________________________________________
# ps_maxpooling_1 (MaxPooling2D)  (None, 73, 73, 32)   0           leaky_re_lu_162[0][0]
# __________________________________________________________________________________________________
# ps_conv_2 (Conv2D)              (None, 71, 71, 32)   9248        ps_maxpooling_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_163 (LeakyReLU)     (None, 71, 71, 32)   0           ps_conv_2[0][0]
# __________________________________________________________________________________________________
# ps_maxpooling_2 (MaxPooling2D)  (None, 35, 35, 32)   0           leaky_re_lu_163[0][0]
# __________________________________________________________________________________________________
# rs_conv_1 (Conv2D)              (None, 35, 35, 64)   18496       ps_maxpooling_2[0][0]
# __________________________________________________________________________________________________
# ps_conv_3 (Conv2D)              (None, 33, 33, 32)   9248        ps_maxpooling_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_164 (LeakyReLU)     (None, 35, 35, 64)   0           rs_conv_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_166 (LeakyReLU)     (None, 33, 33, 32)   0           ps_conv_3[0][0]
# __________________________________________________________________________________________________
# rs_maxpooling_1 (MaxPooling2D)  (None, 17, 17, 64)   0           leaky_re_lu_164[0][0]
# __________________________________________________________________________________________________
# ps_maxpooling_3 (MaxPooling2D)  (None, 16, 16, 32)   0           leaky_re_lu_166[0][0]
# __________________________________________________________________________________________________
# rs_conv_2 (Conv2D)              (None, 17, 17, 64)   36928       rs_maxpooling_1[0][0]
# __________________________________________________________________________________________________
# ps_conv_4 (Conv2D)              (None, 14, 14, 32)   9248        ps_maxpooling_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_165 (LeakyReLU)     (None, 17, 17, 64)   0           rs_conv_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_167 (LeakyReLU)     (None, 14, 14, 32)   0           ps_conv_4[0][0]
# __________________________________________________________________________________________________
# rs_maxpooling_2 (MaxPooling2D)  (None, 8, 8, 64)     0           leaky_re_lu_165[0][0]
# __________________________________________________________________________________________________
# flatten_47 (Flatten)            (None, 6272)         0           leaky_re_lu_167[0][0]
# __________________________________________________________________________________________________
# flatten_46 (Flatten)            (None, 4096)         0           rs_maxpooling_2[0][0]
# __________________________________________________________________________________________________
# dense_94 (Dense)                (None, 20)           125460      flatten_47[0][0]
# __________________________________________________________________________________________________
# dense_92 (Dense)                (None, 20)           81940       flatten_46[0][0]
# __________________________________________________________________________________________________
# dense_95 (Dense)                (None, 20)           420         dense_94[0][0]
# __________________________________________________________________________________________________
# dense_93 (Dense)                (None, 20)           420         dense_92[0][0]
# __________________________________________________________________________________________________
# positionOutput (Dense)          (None, 3)            63          dense_95[0][0]
# __________________________________________________________________________________________________
# rotationOutput (Dense)          (None, 3)            63          dense_93[0][0]
# __________________________________________________________________________________________________
# frameOutput (Dense)             (None, 4)            84          dense_95[0][0]
# ==================================================================================================
# Total params: 296,706
# Trainable params: 296,706
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Training

# %%
training_data_x = X[:int(IMAGES*0.9)]
training_data_y = y[:int(IMAGES*0.9)]
validation_data_x = X[int(IMAGES*0.9):IMAGES]
validation_data_y = y[int(IMAGES*0.9):IMAGES]

history = model.fit(x = training_data_x,
                    y = {"positionOutput": training_data_y[:, 4:7], "rotationOutput": training_data_y[:, 10:13], "frameOutput": training_data_y[:, 0:4]},
                    validation_data = (validation_data_x, {"positionOutput": validation_data_y[:, 4:7], "rotationOutput": validation_data_y[:, 10:13], "frameOutput": validation_data_y[:, 0:4]}),
                    batch_size = 32,
                    epochs = 20)
# Out:
# Epoch 1/20
# 141/141 [==============================] - 125s 889ms/step - loss: 5.9477 - positionOutput_loss: 1.0810 - rotationOutput_loss: 0.2159 - frameOutput_loss: 4.6507 - positionOutput_position_error_x: 8.7003 - positionOutput_position_error_y: 6.8063 - positionOutput_position_error_z: 8.4966 - rotationOutput_acc_20: 0.2153 - rotationOutput_acc_15: 0.1624 - rotationOutput_acc_10: 0.1094 - rotationOutput_acc_5: 0.0547 - val_loss: 1.4295 - val_positionOutput_loss: 0.4177 - val_rotationOutput_loss: 0.2053 - val_frameOutput_loss: 0.8065 - val_positionOutput_position_error_x: 5.8576 - val_positionOutput_position_error_y: 4.9452 - val_positionOutput_position_error_z: 4.9449 - val_rotationOutput_acc_20: 0.2293 - val_rotationOutput_acc_15: 0.1773 - val_rotationOutput_acc_10: 0.1148 - val_rotationOutput_acc_5: 0.0648
# Epoch 2/20
# 141/141 [==============================] - 126s 895ms/step - loss: 0.9153 - positionOutput_loss: 0.2726 - rotationOutput_loss: 0.1958 - frameOutput_loss: 0.4469 - positionOutput_position_error_x: 4.5254 - positionOutput_position_error_y: 3.7806 - positionOutput_position_error_z: 3.8956 - rotationOutput_acc_20: 0.2205 - rotationOutput_acc_15: 0.1675 - rotationOutput_acc_10: 0.1117 - rotationOutput_acc_5: 0.0538 - val_loss: 0.6238 - val_positionOutput_loss: 0.1843 - val_rotationOutput_loss: 0.1950 - val_frameOutput_loss: 0.2445 - val_positionOutput_position_error_x: 3.1369 - val_positionOutput_position_error_y: 3.0372 - val_positionOutput_position_error_z: 3.9107 - val_rotationOutput_acc_20: 0.2473 - val_rotationOutput_acc_15: 0.1895 - val_rotationOutput_acc_10: 0.1207 - val_rotationOutput_acc_5: 0.0629
# Epoch 3/20
# 141/141 [==============================] - 126s 890ms/step - loss: 0.5610 - positionOutput_loss: 0.1697 - rotationOutput_loss: 0.1668 - frameOutput_loss: 0.2245 - positionOutput_position_error_x: 2.9282 - positionOutput_position_error_y: 3.1096 - positionOutput_position_error_z: 3.5487 - rotationOutput_acc_20: 0.2396 - rotationOutput_acc_15: 0.1792 - rotationOutput_acc_10: 0.1199 - rotationOutput_acc_5: 0.0571 - val_loss: 0.4645 - val_positionOutput_loss: 0.1523 - val_rotationOutput_loss: 0.1236 - val_frameOutput_loss: 0.1886 - val_positionOutput_position_error_x: 2.5134 - val_positionOutput_position_error_y: 2.9047 - val_positionOutput_position_error_z: 3.6068 - val_rotationOutput_acc_20: 0.2711 - val_rotationOutput_acc_15: 0.2000 - val_rotationOutput_acc_10: 0.1063 - val_rotationOutput_acc_5: 0.0629
# Epoch 4/20
# 141/141 [==============================] - 128s 906ms/step - loss: 0.4125 - positionOutput_loss: 0.1359 - rotationOutput_loss: 0.1115 - frameOutput_loss: 0.1652 - positionOutput_position_error_x: 2.6549 - positionOutput_position_error_y: 2.6916 - positionOutput_position_error_z: 3.2691 - rotationOutput_acc_20: 0.2955 - rotationOutput_acc_15: 0.2260 - rotationOutput_acc_10: 0.1544 - rotationOutput_acc_5: 0.0792 - val_loss: 0.3471 - val_positionOutput_loss: 0.1138 - val_rotationOutput_loss: 0.0895 - val_frameOutput_loss: 0.1438 - val_positionOutput_position_error_x: 2.4311 - val_positionOutput_position_error_y: 2.3452 - val_positionOutput_position_error_z: 3.1751 - val_rotationOutput_acc_20: 0.4246 - val_rotationOutput_acc_15: 0.3301 - val_rotationOutput_acc_10: 0.2398 - val_rotationOutput_acc_5: 0.1113
# Epoch 5/20
# 141/141 [==============================] - 127s 897ms/step - loss: 0.3275 - positionOutput_loss: 0.1246 - rotationOutput_loss: 0.0579 - frameOutput_loss: 0.1450 - positionOutput_position_error_x: 2.5871 - positionOutput_position_error_y: 2.5196 - positionOutput_position_error_z: 3.1290 - rotationOutput_acc_20: 0.5816 - rotationOutput_acc_15: 0.4772 - rotationOutput_acc_10: 0.3437 - rotationOutput_acc_5: 0.1856 - val_loss: 0.2520 - val_positionOutput_loss: 0.1064 - val_rotationOutput_loss: 0.0265 - val_frameOutput_loss: 0.1191 - val_positionOutput_position_error_x: 2.2874 - val_positionOutput_position_error_y: 2.3388 - val_positionOutput_position_error_z: 3.1079 - val_rotationOutput_acc_20: 0.7832 - val_rotationOutput_acc_15: 0.6566 - val_rotationOutput_acc_10: 0.4699 - val_rotationOutput_acc_5: 0.2879
# Epoch 6/20
# 141/141 [==============================] - 127s 901ms/step - loss: 0.2412 - positionOutput_loss: 0.1055 - rotationOutput_loss: 0.0171 - frameOutput_loss: 0.1186 - positionOutput_position_error_x: 2.4163 - positionOutput_position_error_y: 2.3001 - positionOutput_position_error_z: 2.8540 - rotationOutput_acc_20: 0.8743 - rotationOutput_acc_15: 0.8050 - rotationOutput_acc_10: 0.6414 - rotationOutput_acc_5: 0.3771 - val_loss: 0.2072 - val_positionOutput_loss: 0.0860 - val_rotationOutput_loss: 0.0129 - val_frameOutput_loss: 0.1084 - val_positionOutput_position_error_x: 2.0664 - val_positionOutput_position_error_y: 2.0854 - val_positionOutput_position_error_z: 2.7084 - val_rotationOutput_acc_20: 0.9121 - val_rotationOutput_acc_15: 0.8465 - val_rotationOutput_acc_10: 0.6891 - val_rotationOutput_acc_5: 0.4129
# Epoch 7/20
# 141/141 [==============================] - 126s 893ms/step - loss: 0.2010 - positionOutput_loss: 0.0894 - rotationOutput_loss: 0.0072 - frameOutput_loss: 0.1044 - positionOutput_position_error_x: 2.3274 - positionOutput_position_error_y: 2.1874 - positionOutput_position_error_z: 2.4622 - rotationOutput_acc_20: 0.9549 - rotationOutput_acc_15: 0.9298 - rotationOutput_acc_10: 0.8371 - rotationOutput_acc_5: 0.5567 - val_loss: 0.1855 - val_positionOutput_loss: 0.0777 - val_rotationOutput_loss: 0.0089 - val_frameOutput_loss: 0.0990 - val_positionOutput_position_error_x: 2.0536 - val_positionOutput_position_error_y: 2.1438 - val_positionOutput_position_error_z: 2.3834 - val_rotationOutput_acc_20: 0.9305 - val_rotationOutput_acc_15: 0.8941 - val_rotationOutput_acc_10: 0.7863 - val_rotationOutput_acc_5: 0.5051
# Epoch 8/20
# 141/141 [==============================] - 126s 892ms/step - loss: 0.1871 - positionOutput_loss: 0.0794 - rotationOutput_loss: 0.0051 - frameOutput_loss: 0.1026 - positionOutput_position_error_x: 2.2442 - positionOutput_position_error_y: 2.1190 - positionOutput_position_error_z: 2.2361 - rotationOutput_acc_20: 0.9679 - rotationOutput_acc_15: 0.9537 - rotationOutput_acc_10: 0.8923 - rotationOutput_acc_5: 0.6221 - val_loss: 0.1691 - val_positionOutput_loss: 0.0680 - val_rotationOutput_loss: 0.0062 - val_frameOutput_loss: 0.0949 - val_positionOutput_position_error_x: 1.9712 - val_positionOutput_position_error_y: 1.8926 - val_positionOutput_position_error_z: 2.2449 - val_rotationOutput_acc_20: 0.9570 - val_rotationOutput_acc_15: 0.9375 - val_rotationOutput_acc_10: 0.8414 - val_rotationOutput_acc_5: 0.5797
# Epoch 9/20
# 141/141 [==============================] - 129s 912ms/step - loss: 0.1683 - positionOutput_loss: 0.0701 - rotationOutput_loss: 0.0034 - frameOutput_loss: 0.0948 - positionOutput_position_error_x: 2.1056 - positionOutput_position_error_y: 1.9623 - positionOutput_position_error_z: 2.1034 - rotationOutput_acc_20: 0.9757 - rotationOutput_acc_15: 0.9688 - rotationOutput_acc_10: 0.9391 - rotationOutput_acc_5: 0.7217 - val_loss: 0.1610 - val_positionOutput_loss: 0.0657 - val_rotationOutput_loss: 0.0058 - val_frameOutput_loss: 0.0895 - val_positionOutput_position_error_x: 1.9720 - val_positionOutput_position_error_y: 1.9201 - val_positionOutput_position_error_z: 2.2133 - val_rotationOutput_acc_20: 0.9570 - val_rotationOutput_acc_15: 0.9344 - val_rotationOutput_acc_10: 0.8590 - val_rotationOutput_acc_5: 0.5910
# Epoch 10/20
# 141/141 [==============================] - 130s 924ms/step - loss: 0.1558 - positionOutput_loss: 0.0630 - rotationOutput_loss: 0.0028 - frameOutput_loss: 0.0899 - positionOutput_position_error_x: 2.0333 - positionOutput_position_error_y: 1.8895 - positionOutput_position_error_z: 1.9403 - rotationOutput_acc_20: 0.9750 - rotationOutput_acc_15: 0.9715 - rotationOutput_acc_10: 0.9498 - rotationOutput_acc_5: 0.7477 - val_loss: 0.1506 - val_positionOutput_loss: 0.0570 - val_rotationOutput_loss: 0.0047 - val_frameOutput_loss: 0.0889 - val_positionOutput_position_error_x: 1.8842 - val_positionOutput_position_error_y: 1.8232 - val_positionOutput_position_error_z: 1.8911 - val_rotationOutput_acc_20: 0.9727 - val_rotationOutput_acc_15: 0.9668 - val_rotationOutput_acc_10: 0.9090 - val_rotationOutput_acc_5: 0.6473
# Epoch 11/20
# 141/141 [==============================] - 135s 960ms/step - loss: 0.1483 - positionOutput_loss: 0.0572 - rotationOutput_loss: 0.0021 - frameOutput_loss: 0.0890 - positionOutput_position_error_x: 1.9554 - positionOutput_position_error_y: 1.8421 - positionOutput_position_error_z: 1.7769 - rotationOutput_acc_20: 0.9807 - rotationOutput_acc_15: 0.9801 - rotationOutput_acc_10: 0.9688 - rotationOutput_acc_5: 0.8237 - val_loss: 0.1465 - val_positionOutput_loss: 0.0535 - val_rotationOutput_loss: 0.0043 - val_frameOutput_loss: 0.0886 - val_positionOutput_position_error_x: 1.7838 - val_positionOutput_position_error_y: 1.8779 - val_positionOutput_position_error_z: 1.8444 - val_rotationOutput_acc_20: 0.9688 - val_rotationOutput_acc_15: 0.9629 - val_rotationOutput_acc_10: 0.8992 - val_rotationOutput_acc_5: 0.6637
# Epoch 12/20
# 141/141 [==============================] - 131s 927ms/step - loss: 0.1406 - positionOutput_loss: 0.0514 - rotationOutput_loss: 0.0018 - frameOutput_loss: 0.0874 - positionOutput_position_error_x: 1.8861 - positionOutput_position_error_y: 1.7647 - positionOutput_position_error_z: 1.6466 - rotationOutput_acc_20: 0.9836 - rotationOutput_acc_15: 0.9825 - rotationOutput_acc_10: 0.9787 - rotationOutput_acc_5: 0.8616 - val_loss: 0.1381 - val_positionOutput_loss: 0.0474 - val_rotationOutput_loss: 0.0042 - val_frameOutput_loss: 0.0864 - val_positionOutput_position_error_x: 1.6867 - val_positionOutput_position_error_y: 1.8058 - val_positionOutput_position_error_z: 1.6482 - val_rotationOutput_acc_20: 0.9668 - val_rotationOutput_acc_15: 0.9551 - val_rotationOutput_acc_10: 0.9102 - val_rotationOutput_acc_5: 0.6266
# Epoch 13/20
# 141/141 [==============================] - 130s 925ms/step - loss: 0.1354 - positionOutput_loss: 0.0476 - rotationOutput_loss: 0.0015 - frameOutput_loss: 0.0863 - positionOutput_position_error_x: 1.8142 - positionOutput_position_error_y: 1.7158 - positionOutput_position_error_z: 1.5601 - rotationOutput_acc_20: 0.9850 - rotationOutput_acc_15: 0.9848 - rotationOutput_acc_10: 0.9808 - rotationOutput_acc_5: 0.8855 - val_loss: 0.1396 - val_positionOutput_loss: 0.0486 - val_rotationOutput_loss: 0.0039 - val_frameOutput_loss: 0.0871 - val_positionOutput_position_error_x: 1.7944 - val_positionOutput_position_error_y: 1.7541 - val_positionOutput_position_error_z: 1.5723 - val_rotationOutput_acc_20: 0.9668 - val_rotationOutput_acc_15: 0.9609 - val_rotationOutput_acc_10: 0.9141 - val_rotationOutput_acc_5: 0.6719
# Epoch 14/20
# 141/141 [==============================] - 132s 934ms/step - loss: 0.1326 - positionOutput_loss: 0.0459 - rotationOutput_loss: 0.0013 - frameOutput_loss: 0.0854 - positionOutput_position_error_x: 1.7772 - positionOutput_position_error_y: 1.6831 - positionOutput_position_error_z: 1.5727 - rotationOutput_acc_20: 0.9863 - rotationOutput_acc_15: 0.9861 - rotationOutput_acc_10: 0.9835 - rotationOutput_acc_5: 0.9035 - val_loss: 0.1358 - val_positionOutput_loss: 0.0470 - val_rotationOutput_loss: 0.0040 - val_frameOutput_loss: 0.0849 - val_positionOutput_position_error_x: 1.7140 - val_positionOutput_position_error_y: 1.7709 - val_positionOutput_position_error_z: 1.4936 - val_rotationOutput_acc_20: 0.9707 - val_rotationOutput_acc_15: 0.9668 - val_rotationOutput_acc_10: 0.9180 - val_rotationOutput_acc_5: 0.6773
# Epoch 15/20
# 141/141 [==============================] - 126s 892ms/step - loss: 0.1310 - positionOutput_loss: 0.0441 - rotationOutput_loss: 0.0012 - frameOutput_loss: 0.0857 - positionOutput_position_error_x: 1.7811 - positionOutput_position_error_y: 1.6920 - positionOutput_position_error_z: 1.4455 - rotationOutput_acc_20: 0.9891 - rotationOutput_acc_15: 0.9887 - rotationOutput_acc_10: 0.9876 - rotationOutput_acc_5: 0.9305 - val_loss: 0.1295 - val_positionOutput_loss: 0.0422 - val_rotationOutput_loss: 0.0037 - val_frameOutput_loss: 0.0836 - val_positionOutput_position_error_x: 1.6210 - val_positionOutput_position_error_y: 1.7080 - val_positionOutput_position_error_z: 1.4970 - val_rotationOutput_acc_20: 0.9766 - val_rotationOutput_acc_15: 0.9707 - val_rotationOutput_acc_10: 0.9297 - val_rotationOutput_acc_5: 0.6727
# Epoch 16/20
# 141/141 [==============================] - 127s 898ms/step - loss: 0.1255 - positionOutput_loss: 0.0411 - rotationOutput_loss: 9.9743e-04 - frameOutput_loss: 0.0833 - positionOutput_position_error_x: 1.7012 - positionOutput_position_error_y: 1.6017 - positionOutput_position_error_z: 1.4679 - rotationOutput_acc_20: 0.9891 - rotationOutput_acc_15: 0.9889 - rotationOutput_acc_10: 0.9883 - rotationOutput_acc_5: 0.9423 - val_loss: 0.1321 - val_positionOutput_loss: 0.0425 - val_rotationOutput_loss: 0.0035 - val_frameOutput_loss: 0.0861 - val_positionOutput_position_error_x: 1.6767 - val_positionOutput_position_error_y: 1.7098 - val_positionOutput_position_error_z: 1.5046 - val_rotationOutput_acc_20: 0.9727 - val_rotationOutput_acc_15: 0.9648 - val_rotationOutput_acc_10: 0.9336 - val_rotationOutput_acc_5: 0.6938
# Epoch 17/20
# 141/141 [==============================] - 126s 893ms/step - loss: 0.1219 - positionOutput_loss: 0.0375 - rotationOutput_loss: 9.2806e-04 - frameOutput_loss: 0.0834 - positionOutput_position_error_x: 1.6670 - positionOutput_position_error_y: 1.5579 - positionOutput_position_error_z: 1.3042 - rotationOutput_acc_20: 0.9871 - rotationOutput_acc_15: 0.9871 - rotationOutput_acc_10: 0.9860 - rotationOutput_acc_5: 0.9484 - val_loss: 0.1252 - val_positionOutput_loss: 0.0398 - val_rotationOutput_loss: 0.0039 - val_frameOutput_loss: 0.0815 - val_positionOutput_position_error_x: 1.6101 - val_positionOutput_position_error_y: 1.6175 - val_positionOutput_position_error_z: 1.3926 - val_rotationOutput_acc_20: 0.9688 - val_rotationOutput_acc_15: 0.9609 - val_rotationOutput_acc_10: 0.9316 - val_rotationOutput_acc_5: 0.6965
# Epoch 18/20
# 141/141 [==============================] - 126s 896ms/step - loss: 0.1183 - positionOutput_loss: 0.0365 - rotationOutput_loss: 8.3209e-04 - frameOutput_loss: 0.0810 - positionOutput_position_error_x: 1.6200 - positionOutput_position_error_y: 1.5266 - positionOutput_position_error_z: 1.3435 - rotationOutput_acc_20: 0.9877 - rotationOutput_acc_15: 0.9877 - rotationOutput_acc_10: 0.9868 - rotationOutput_acc_5: 0.9621 - val_loss: 0.1240 - val_positionOutput_loss: 0.0391 - val_rotationOutput_loss: 0.0034 - val_frameOutput_loss: 0.0815 - val_positionOutput_position_error_x: 1.5494 - val_positionOutput_position_error_y: 1.5628 - val_positionOutput_position_error_z: 1.5192 - val_rotationOutput_acc_20: 0.9746 - val_rotationOutput_acc_15: 0.9707 - val_rotationOutput_acc_10: 0.9355 - val_rotationOutput_acc_5: 0.7098
# Epoch 19/20
# 141/141 [==============================] - 127s 900ms/step - loss: 0.1140 - positionOutput_loss: 0.0330 - rotationOutput_loss: 7.8236e-04 - frameOutput_loss: 0.0802 - positionOutput_position_error_x: 1.5730 - positionOutput_position_error_y: 1.4603 - positionOutput_position_error_z: 1.2169 - rotationOutput_acc_20: 0.9896 - rotationOutput_acc_15: 0.9896 - rotationOutput_acc_10: 0.9891 - rotationOutput_acc_5: 0.9634 - val_loss: 0.1186 - val_positionOutput_loss: 0.0368 - val_rotationOutput_loss: 0.0036 - val_frameOutput_loss: 0.0782 - val_positionOutput_position_error_x: 1.5320 - val_positionOutput_position_error_y: 1.6335 - val_positionOutput_position_error_z: 1.3766 - val_rotationOutput_acc_20: 0.9707 - val_rotationOutput_acc_15: 0.9629 - val_rotationOutput_acc_10: 0.9316 - val_rotationOutput_acc_5: 0.7031
# Epoch 20/20
# 141/141 [==============================] - 129s 913ms/step - loss: 0.1118 - positionOutput_loss: 0.0317 - rotationOutput_loss: 6.8193e-04 - frameOutput_loss: 0.0795 - positionOutput_position_error_x: 1.5436 - positionOutput_position_error_y: 1.4436 - positionOutput_position_error_z: 1.1864 - rotationOutput_acc_20: 0.9883 - rotationOutput_acc_15: 0.9883 - rotationOutput_acc_10: 0.9878 - rotationOutput_acc_5: 0.9717 - val_loss: 0.1161 - val_positionOutput_loss: 0.0332 - val_rotationOutput_loss: 0.0034 - val_frameOutput_loss: 0.0795 - val_positionOutput_position_error_x: 1.4890 - val_positionOutput_position_error_y: 1.5158 - val_positionOutput_position_error_z: 1.2112 - val_rotationOutput_acc_20: 0.9766 - val_rotationOutput_acc_15: 0.9727 - val_rotationOutput_acc_10: 0.9277 - val_rotationOutput_acc_5: 0.7207

# %%
for k in history.history.keys():
    print(k)

fig, axs = plt.subplots(ncols = 1, nrows = 8, figsize=(10,30))

axs[0].plot(history.history['loss'], label = "training")
axs[0].plot(history.history['val_loss'], label = "validation")
axs[0].set_ylabel('loss')
axs[0].set_xlabel('epoch')
axs[0].legend(loc='upper right')
axs[0].set_title("Total loss")

axs[1].plot(history.history['positionOutput_loss'], label = "training")
axs[1].plot(history.history['val_positionOutput_loss'], label = "validation")
axs[1].set_xlabel('epoch')
axs[1].legend(loc='upper right')
axs[1].set_title("Position loss")

axs[2].plot(history.history['positionOutput_position_error_x'], label = "X Axis")
axs[2].plot(history.history['positionOutput_position_error_y'], label = "Y Axis")
axs[2].plot(history.history['positionOutput_position_error_z'], label = "Z Axis")
axs[2].set_ylabel('Mean absolute error')
axs[2].set_xlabel('epoch')
axs[2].legend(loc='upper right')
axs[2].set_title("Position error training")

axs[3].plot(history.history['val_positionOutput_position_error_x'], label = "X Axis")
axs[3].plot(history.history['val_positionOutput_position_error_y'], label = "Y Axis")
axs[3].plot(history.history['val_positionOutput_position_error_z'], label = "Z Axis")
axs[3].set_ylabel('Mean absolute error')
axs[3].set_xlabel('epoch')
axs[3].legend(loc='upper right')
axs[3].set_title("Position error validation")

axs[4].plot(history.history['rotationOutput_loss'], label = "training")
axs[4].plot(history.history['val_rotationOutput_loss'], label = "validation")
axs[4].set_xlabel('epoch')
axs[4].legend(loc='upper right')
axs[4].set_title("Rotation loss")

axs[5].plot(history.history['rotationOutput_acc_20'], label = "training")
axs[5].plot(history.history['val_rotationOutput_acc_20'], label = "validation")
axs[5].set_xlabel('epoch')
axs[5].legend(loc='lower right')
axs[5].set_title("ACC_20")

axs[6].plot(history.history['rotationOutput_acc_15'], label = "training")
axs[6].plot(history.history['val_rotationOutput_acc_15'], label = "validation")
axs[6].set_xlabel('epoch')
axs[6].legend(loc='lower right')
axs[6].set_title("ACC_15")

axs[7].plot(history.history['rotationOutput_acc_5'], label = "training")
axs[7].plot(history.history['val_rotationOutput_acc_5'], label = "validation")
axs[7].set_xlabel('epoch')
axs[7].legend(loc='lower right')
axs[7].set_title("ACC_5")

plt.subplots_adjust(hspace=0.5)
plt.show()
# Out:
# loss
# positionOutput_loss
# rotationOutput_loss
# frameOutput_loss
# positionOutput_position_error_x
# positionOutput_position_error_y
# positionOutput_position_error_z
# rotationOutput_acc_20
# rotationOutput_acc_15
# rotationOutput_acc_10
# rotationOutput_acc_5
# val_loss
# val_positionOutput_loss
# val_rotationOutput_loss
# val_frameOutput_loss
# val_positionOutput_position_error_x
# val_positionOutput_position_error_y
# val_positionOutput_position_error_z
# val_rotationOutput_acc_20
# val_rotationOutput_acc_15
# val_rotationOutput_acc_10
# val_rotationOutput_acc_5

# %% [markdown]
# # Results
# ### On validation data

# %%
# random_index = random.randrange(len(training_data))
# Images from trainig set
# random_index = random.randrange(IMAGES*0.8)

# Images from validation set
random_index = random.randrange(IMAGES*0.8 ,IMAGES)

prediction = model.predict(X[random_index].reshape(1, IMG_SIZE, IMG_SIZE, 3))

fig, axs = plt.subplots(ncols = 3, figsize = (15, 15))

axs[0].imshow(X[random_index][:, :, 0], cmap="Reds")
axs[1].imshow(X[random_index][:, :, 1], cmap="Greens")
axs[2].imshow(X[random_index][:, :, 2], cmap="Blues")

frame_og = y[random_index][:4]*100
pos_og = y[random_index][4:7]*10
rot_og = [int(RGBToAngle(y[random_index][10:13]))]

frame_pred = [int(p*100) for p in prediction[2][0]]
pos_pred = [int(p*10) for p in prediction[0][0]]
rot_pred = [int(RGBToAngle(prediction[1][0][0:3]))]

pos_error = int(sum((abs(pos_pred-pos_og)/30)*100)/3)
rot_error = int(abs((rot_pred[0]-rot_og[0])/360)*100)

axs[1].set_title(f"Labels:\
\n(bx, by, bw, bh): {frame_og}\
\n(posX, posY, posZ): {pos_og}\
\n(rotX, rotY): {rot_og}\n\
Predicted:\
\n(bx, by, bw, bh): {frame_pred}\
\n(posX, posY, posZ): {pos_pred}\
\n(rotY): {rot_pred}\
\nError\
\nPosition: {pos_error}%\
\nRotation: {rot_error}%")

plt.show()

# %% [markdown]
# ### On training data

# %%
random_index = random.randrange(IMAGES)

prediction = model.predict(X[random_index].reshape(1, IMG_SIZE, IMG_SIZE, 3))

fig, axs = plt.subplots(ncols = 3, figsize = (15, 15))

axs[0].imshow(X[random_index][:, :, 0], cmap="Reds")
axs[1].imshow(X[random_index][:, :, 1], cmap="Greens")
axs[2].imshow(X[random_index][:, :, 2], cmap="Blues")

frame_og = y[random_index][:4]*100
pos_og = y[random_index][4:7]*10
rot_og = [int(RGBToAngle(y[random_index][7:10])), int(RGBToAngle(y[random_index][10:13]))]

frame_pred = [int(p*100) for p in prediction[2][0]]
pos_pred = [int(p*10) for p in prediction[0][0]]
rot_pred = [int(RGBToAngle(prediction[1][0][0:3])), int(RGBToAngle(prediction[1][0][3:7]))]

pos_error = int(sum((abs(pos_pred-pos_og)/30)*100))
rot_error = int(sum([abs((rot_pred[0]-rot_og[0])/360), abs(rot_pred[1]-rot_og[1])/360])*100)

axs[1].set_title(f"Labels:\
\n(bx, by, bw, bh): {frame_og}\
\n(posX, posY, posZ): {pos_og}\
\n(rotX, rotY): {rot_og}\n\
Predicted:\
\n(bx, by, bw, bh): {frame_pred}\
\n(posX, posY, posZ): {pos_pred}\
\n(rotX, rotY): {rot_pred}\
\nError\
\nPosition: {pos_error}%\
\nRotation: {rot_error}%")

plt.show()

# %% [markdown]
# # Layer output extraction

# %%
def extract_layer_data(layer):
    submodel = keras.Model(inputs = model.input, outputs = layer.output)
    submodel_output = submodel.predict(np.array(X[random_index]).reshape(1, IMG_SIZE, IMG_SIZE, 3))
    output_shape = submodel_output.shape
    
    graph_size = 10
    
    index = 0
    if (len(output_shape) != 2):
        if(output_shape[-1]>=4):
            fig, axs = plt.subplots(4, int(output_shape[-1]/4), figsize=(graph_size, graph_size))
            fig.suptitle(f"{layer.name}, [{output_shape}]")
            for col in range(0, 4):
                for row in range(0, int(output_shape[-1]/4)):
                    axs[col, row].imshow(submodel_output[0, :, :, index], cmap="Greys")
                    index += 1
                    axs[col, row].axis('off')
            
        else:
            fig, axs = plt.subplots(ncols = output_shape[-1], figsize=(graph_size, graph_size))
            for col in range(0, output_shape[-1]):
                axs[col].imshow(submodel_output[0, :, :, index], cmap="Greys")
                if(int(output_shape[-1]/2) == col):
                    axs[col].set_title(f"{layer.name}, [{output_shape}]")
                index += 1
                axs[col].axis('off')
    plt.tight_layout()
    
# for layer in model.layers:
#     extract_layer_data(layer)

# %%
from IPython.core.display import HTML
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}

</style>
""")
# Out:
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
#
# </style>

# %%
plt.rcParams.update({'font.size': 15})

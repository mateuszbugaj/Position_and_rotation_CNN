# %% [markdown]
# # Position and rotation estimation with pooling layers and RGB images

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
import cv2
import random
import math

import tensorflow as tf
tf.get_logger().setLevel('ERROR')
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow.keras.backend as K
from tensorflow.keras import Input
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, LeakyReLU

# %% [markdown]
# # Preparing data

# %%
DATADIR = "dataset_generator/images/pos_and_rot_3/"
JSON_file_name = "data.txt"
IMAGES = 2_000
OG_IMG_SIZE = 800
IMG_SIZE = 150

# %%
data_json = []
for line in open(DATADIR + JSON_file_name, 'r'):
    data_json.append(json.loads(line))
    
dataset = [] # [x, y]

for img in os.listdir(DATADIR):
    if(img.endswith(".jpg")):
        img_array = cv2.imread(os.path.join(DATADIR, img))
        img_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))

        img_index = int(img.strip(".jpg"))
        for label in data_json:
            if(label['index'] == img_index):
                choosen_label = {'bx': label['bx'], 
                                 'by': label['by'], 
                                 'bw': label['bw'], 
                                 'bh': label['bh'], 
                                 'posX': label['posX'], 
                                 'posY': label['posY'], 
                                 'posZ': label['posZ'],
                                 'rotX': label['rotX'],
                                 'rotY': label['rotY']}
                
                xy = [img_array, choosen_label]
                dataset.append(xy)
                
        if(len(dataset)%500 ==0):
            print(f"{len(dataset)} images loaded")
        
        if(len(dataset) >= IMAGES):
            print("All images loaded")
            break
            
IMAGES = len(dataset)
print(f"{IMAGES} in total")
# Out:
# 500 images loaded
# 1000 images loaded
# 1500 images loaded
# 2000 images loaded
# All images loaded
# 2000 in total

# %% [markdown]
# # Creating training dataset

# %%
X = []
y = []

shuffled_indices = random.sample(range(0, IMAGES), IMAGES)

for i in shuffled_indices:
    
    pixels = dataset[i][0]
    pixels = pixels.astype('uint8')
    X.append(pixels)
    
    y_labels = [dataset[i][1]['bx'], 
                dataset[i][1]['by'], 
                dataset[i][1]['bw'], 
                dataset[i][1]['bh'], 
                dataset[i][1]['posX'], 
                dataset[i][1]['posY'], 
                dataset[i][1]['posZ'],
                dataset[i][1]['rotX'],
                dataset[i][1]['rotY']]
    
    y.append(y_labels)

# Global Standardization
X = (np.array(X).reshape(IMAGES, IMG_SIZE, IMG_SIZE, 3) - np.mean(X)) / np.std(X)
    
for index, ya in enumerate(y):
    y[index] = np.array([ya[0]/100, ya[1]/100, ya[2]/100, ya[3]/100, ya[4]/10, ya[5]/10, ya[6]/10, ya[7]/360, ya[8]/360])
    
y = np.array(y)

print(f"X shape: {X.shape}\ny shape: {y.shape}")
# Out:
# X shape: (2000, 150, 150, 3)
# y shape: (2000, 9)

# %%
random_index = random.randrange(IMAGES)
fig, axs = plt.subplots(ncols = 3, figsize = (15, 15))

axs[0].imshow(X[random_index][:, :, 0], cmap="Reds")
axs[1].imshow(X[random_index][:, :, 1], cmap="Greens")
axs[2].imshow(X[random_index][:, :, 2], cmap="Blues")

axs[1].set_title(f"Labels:\n(bx, by, bw, bh): {y[random_index][:4]}\
\n(posX, posY, posZ): {y[random_index][4:7]}\
\n(rotX, rotY): {y[random_index][7:9]}")

plt.show()

# %% [markdown]
# # Model

# %% [markdown]
# ### Custom accuracy metric

# %%
def acc15(y_true, y_pred):
    threshold = 15
    count = tf.reduce_sum(tf.cast(K.less(K.abs(y_true-y_pred), threshold), tf.float32))

    return count

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
inputs = Input(name = "Inputs",
              shape = (IMG_SIZE, IMG_SIZE, 3))

# Main Stream
mainStream = Conv2D(name = "ms_conv_1",
                   filters = 16,
                   kernel_size = 3,
                   strides = 1,
                   padding = "valid",
                   kernel_initializer='he_uniform')(inputs)

mainStream = LeakyReLU()(mainStream)

mainStream = MaxPooling2D(name="ms_maxpooling_1", 
                          pool_size = (2, 2), 
                          strides = 2)(mainStream)

mainStream = Conv2D(name = "ms_conv_2",
                   filters = 16,
                   kernel_size = 3,
                   strides = 1,
                   padding = "valid",
#                    kernel_initializer=tf.keras.initializers.GlorotUniform())(mainStream)
                    kernel_initializer='he_uniform')(mainStream)


mainStream = LeakyReLU()(mainStream)

mainStream = MaxPooling2D(name="ms_maxpooling_2", 
                          pool_size = (2, 2), 
                          strides = 2)(mainStream)

mainStream = Conv2D(name = "ms_conv_3",
                   filters = 32,
                   kernel_size = 3,
                   strides = 1,
                   padding = "valid",
                   kernel_initializer='he_uniform')(mainStream)

mainStream = LeakyReLU()(mainStream)

mainStream = MaxPooling2D(name="ms_maxpooling_3", 
                          pool_size = (2, 2), 
                          strides = 2)(mainStream)


# Position Stream
positionStream = MaxPooling2D(name="ps_maxpooling_1", 
                          pool_size = (2, 2), 
                          strides = 1)(mainStream)

positionStream = MaxPooling2D(name="ps_maxpooling_2", 
                          pool_size = (2, 2), 
                          strides = 2)(positionStream)

positionStream = Flatten()(positionStream)

# Frame Stream
frameStream = Flatten()(positionStream)
frameStream = Dense(20, activation = "relu")(frameStream)
frameStream = Dense(20, activation = "relu")(frameStream)
frameStream = Dense(4, name = "frameOutput")(frameStream)

positionStream = Dense(20, activation = "relu")(positionStream)
positionStream = Dense(20, activation = "relu")(positionStream)
positionStream = Dense(3, name = "positionOutput")(positionStream)

# Rotation Stream
roationStream = Conv2D(name = "rs_conv_1",
                   filters = 32,
                   kernel_size = 3,
                   strides = 1,
                   padding = "same",
                   kernel_initializer='he_uniform')(mainStream)

roationStream = LeakyReLU()(roationStream)

roationStream = Conv2D(name = "rs_conv_2",
                   filters = 32,
                   kernel_size = 3,
                   strides = 1,
                   padding = "same",
                   kernel_initializer='he_uniform')(mainStream)

roationStream = LeakyReLU()(roationStream)

roationStream = Flatten()(roationStream)
roationStream = Dense(500, activation = "relu")(roationStream)
roationStream = Dense(500, activation = "relu")(roationStream)
roationStream = Dense(2, name = "rotationOutput")(roationStream)


model = keras.Model(inputs, [positionStream, roationStream, frameStream], name = "Model")

model_optimizer = tf.keras.optimizers.Adam(
    learning_rate=0.001,
    beta_1=0.9,
    amsgrad=False)

model_loss = tf.keras.losses.MeanSquaredError()

model.compile(optimizer = model_optimizer,
             loss = [model_loss, model_loss, model_loss])

model.summary()
keras.utils.plot_model(model, "model.png", show_shapes=True)
# Out:
# Model: "Model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Inputs (InputLayer)             [(None, 150, 150, 3) 0
# __________________________________________________________________________________________________
# ms_conv_1 (Conv2D)              (None, 148, 148, 16) 448         Inputs[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 148, 148, 16) 0           ms_conv_1[0][0]
# __________________________________________________________________________________________________
# ms_maxpooling_1 (MaxPooling2D)  (None, 74, 74, 16)   0           leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# ms_conv_2 (Conv2D)              (None, 72, 72, 16)   2320        ms_maxpooling_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, 72, 72, 16)   0           ms_conv_2[0][0]
# __________________________________________________________________________________________________
# ms_maxpooling_2 (MaxPooling2D)  (None, 36, 36, 16)   0           leaky_re_lu_36[0][0]
# __________________________________________________________________________________________________
# ms_conv_3 (Conv2D)              (None, 34, 34, 32)   4640        ms_maxpooling_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)      (None, 34, 34, 32)   0           ms_conv_3[0][0]
# __________________________________________________________________________________________________
# ms_maxpooling_3 (MaxPooling2D)  (None, 17, 17, 32)   0           leaky_re_lu_37[0][0]
# __________________________________________________________________________________________________
# ps_maxpooling_1 (MaxPooling2D)  (None, 16, 16, 32)   0           ms_maxpooling_3[0][0]
# __________________________________________________________________________________________________
# ps_maxpooling_2 (MaxPooling2D)  (None, 8, 8, 32)     0           ps_maxpooling_1[0][0]
# __________________________________________________________________________________________________
# rs_conv_2 (Conv2D)              (None, 17, 17, 32)   9248        ms_maxpooling_3[0][0]
# __________________________________________________________________________________________________
# flatten_21 (Flatten)            (None, 2048)         0           ps_maxpooling_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, 17, 17, 32)   0           rs_conv_2[0][0]
# __________________________________________________________________________________________________
# flatten_23 (Flatten)            (None, 9248)         0           leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# flatten_22 (Flatten)            (None, 2048)         0           flatten_21[0][0]
# __________________________________________________________________________________________________
# dense_44 (Dense)                (None, 20)           40980       flatten_21[0][0]
# __________________________________________________________________________________________________
# dense_46 (Dense)                (None, 500)          4624500     flatten_23[0][0]
# __________________________________________________________________________________________________
# dense_42 (Dense)                (None, 20)           40980       flatten_22[0][0]
# __________________________________________________________________________________________________
# dense_45 (Dense)                (None, 20)           420         dense_44[0][0]
# __________________________________________________________________________________________________
# dense_47 (Dense)                (None, 500)          250500      dense_46[0][0]
# __________________________________________________________________________________________________
# dense_43 (Dense)                (None, 20)           420         dense_42[0][0]
# __________________________________________________________________________________________________
# positionOutput (Dense)          (None, 3)            63          dense_45[0][0]
# __________________________________________________________________________________________________
# rotationOutput (Dense)          (None, 2)            1002        dense_47[0][0]
# __________________________________________________________________________________________________
# frameOutput (Dense)             (None, 4)            84          dense_43[0][0]
# ==================================================================================================
# Total params: 4,975,605
# Trainable params: 4,975,605
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Training

# %%
history = model.fit(x = X,
                   y = {"frameOutput": y[:, 0:4], "positionOutput": y[:, 4:7], "rotationOutput": y[:, 7:9]},
                   batch_size = 32,
                   epochs = 15,
                   validation_split = 0.2)
# Out:
# Epoch 1/15
# 50/50 [==============================] - 9s 181ms/step - loss: 15.9478 - positionOutput_loss: 0.9439 - rotationOutput_loss: 13.0569 - frameOutput_loss: 1.9470 - val_loss: 1.3649 - val_positionOutput_loss: 0.3559 - val_rotationOutput_loss: 0.0567 - val_frameOutput_loss: 0.9523
# Epoch 2/15
# 50/50 [==============================] - 9s 172ms/step - loss: 1.1717 - positionOutput_loss: 0.3123 - rotationOutput_loss: 0.0541 - frameOutput_loss: 0.8053 - val_loss: 1.0170 - val_positionOutput_loss: 0.2861 - val_rotationOutput_loss: 0.0598 - val_frameOutput_loss: 0.6710
# Epoch 3/15
# 50/50 [==============================] - 9s 175ms/step - loss: 0.8741 - positionOutput_loss: 0.2425 - rotationOutput_loss: 0.0451 - frameOutput_loss: 0.5865 - val_loss: 0.8577 - val_positionOutput_loss: 0.2235 - val_rotationOutput_loss: 0.0640 - val_frameOutput_loss: 0.5703
# Epoch 4/15
# 50/50 [==============================] - 9s 174ms/step - loss: 0.7351 - positionOutput_loss: 0.1886 - rotationOutput_loss: 0.0417 - frameOutput_loss: 0.5047 - val_loss: 0.7541 - val_positionOutput_loss: 0.1865 - val_rotationOutput_loss: 0.0531 - val_frameOutput_loss: 0.5145
# Epoch 5/15
# 50/50 [==============================] - 9s 172ms/step - loss: 0.6432 - positionOutput_loss: 0.1566 - rotationOutput_loss: 0.0381 - frameOutput_loss: 0.4485 - val_loss: 0.6806 - val_positionOutput_loss: 0.1651 - val_rotationOutput_loss: 0.0553 - val_frameOutput_loss: 0.4602
# Epoch 6/15
# 50/50 [==============================] - 9s 176ms/step - loss: 0.5735 - positionOutput_loss: 0.1361 - rotationOutput_loss: 0.0275 - frameOutput_loss: 0.4099 - val_loss: 0.6533 - val_positionOutput_loss: 0.1512 - val_rotationOutput_loss: 0.0582 - val_frameOutput_loss: 0.4439
# Epoch 7/15
# 50/50 [==============================] - 9s 180ms/step - loss: 0.5288 - positionOutput_loss: 0.1253 - rotationOutput_loss: 0.0274 - frameOutput_loss: 0.3761 - val_loss: 0.6408 - val_positionOutput_loss: 0.1516 - val_rotationOutput_loss: 0.0702 - val_frameOutput_loss: 0.4190
# Epoch 8/15
# 50/50 [==============================] - 9s 179ms/step - loss: 0.4923 - positionOutput_loss: 0.1145 - rotationOutput_loss: 0.0190 - frameOutput_loss: 0.3588 - val_loss: 0.5946 - val_positionOutput_loss: 0.1420 - val_rotationOutput_loss: 0.0564 - val_frameOutput_loss: 0.3962
# Epoch 9/15
# 50/50 [==============================] - 9s 189ms/step - loss: 0.4532 - positionOutput_loss: 0.1043 - rotationOutput_loss: 0.0150 - frameOutput_loss: 0.3339 - val_loss: 0.6037 - val_positionOutput_loss: 0.1371 - val_rotationOutput_loss: 0.0682 - val_frameOutput_loss: 0.3983
# Epoch 10/15
# 50/50 [==============================] - 9s 176ms/step - loss: 0.4360 - positionOutput_loss: 0.1010 - rotationOutput_loss: 0.0140 - frameOutput_loss: 0.3210 - val_loss: 0.5626 - val_positionOutput_loss: 0.1337 - val_rotationOutput_loss: 0.0616 - val_frameOutput_loss: 0.3672
# Epoch 11/15
# 50/50 [==============================] - 9s 175ms/step - loss: 0.4013 - positionOutput_loss: 0.0956 - rotationOutput_loss: 0.0092 - frameOutput_loss: 0.2965 - val_loss: 0.5554 - val_positionOutput_loss: 0.1327 - val_rotationOutput_loss: 0.0609 - val_frameOutput_loss: 0.3617
# Epoch 12/15
# 50/50 [==============================] - 9s 179ms/step - loss: 0.3794 - positionOutput_loss: 0.0905 - rotationOutput_loss: 0.0062 - frameOutput_loss: 0.2826 - val_loss: 0.5375 - val_positionOutput_loss: 0.1228 - val_rotationOutput_loss: 0.0623 - val_frameOutput_loss: 0.3525
# Epoch 13/15
# 50/50 [==============================] - 9s 180ms/step - loss: 0.3464 - positionOutput_loss: 0.0839 - rotationOutput_loss: 0.0045 - frameOutput_loss: 0.2579 - val_loss: 0.5360 - val_positionOutput_loss: 0.1225 - val_rotationOutput_loss: 0.0589 - val_frameOutput_loss: 0.3546
# Epoch 14/15
# 50/50 [==============================] - 9s 177ms/step - loss: 0.3205 - positionOutput_loss: 0.0814 - rotationOutput_loss: 0.0030 - frameOutput_loss: 0.2361 - val_loss: 0.4719 - val_positionOutput_loss: 0.1211 - val_rotationOutput_loss: 0.0608 - val_frameOutput_loss: 0.2900
# Epoch 15/15
# 50/50 [==============================] - 9s 178ms/step - loss: 0.2964 - positionOutput_loss: 0.0799 - rotationOutput_loss: 0.0029 - frameOutput_loss: 0.2136 - val_loss: 0.4588 - val_positionOutput_loss: 0.1175 - val_rotationOutput_loss: 0.0603 - val_frameOutput_loss: 0.2810

# %%
for k in history.history.keys():
    print(k)

fig, axs = plt.subplots(ncols = 1, nrows = 1, figsize=(10,5))

axs.plot(history.history['loss'], label = "loss")
axs.plot(history.history['val_loss'], label = "val_loss")
axs.set_ylabel('loss')
axs.set_xlabel('epoch')
axs.legend(loc='upper right')

plt.show()
# Out:
# loss
# positionOutput_loss
# rotationOutput_loss
# frameOutput_loss
# val_loss
# val_positionOutput_loss
# val_rotationOutput_loss
# val_frameOutput_loss

# %% [markdown]
# # Results

# %%
random_index = random.randrange(IMAGES)

prediction = model.predict(X[random_index].reshape(1, IMG_SIZE, IMG_SIZE, 3))

fig, axs = plt.subplots(ncols = 3, figsize = (15, 15))

axs[0].imshow(X[random_index][:, :, 0], cmap="Reds")
axs[1].imshow(X[random_index][:, :, 1], cmap="Greens")
axs[2].imshow(X[random_index][:, :, 2], cmap="Blues")

frame_og = y[random_index][:4]*100
pos_og = y[random_index][4:7]*10
rot_og = y[random_index][7:9]*360

frame_pred = [int(p*100) for p in prediction[2][0]]
pos_pred = [int(p*10) for p in prediction[0][0]]
rot_pred = [int(p*360) for p in prediction[1][0]]

pos_error = int(sum((abs(pos_pred-pos_og)/30)*100))
rot_error = int(sum(abs((rot_pred-rot_og)/360)*100))

axs[1].set_title(f"Labels:\
\n(bx, by, bw, bh): {frame_og}\
\n(posX, posY, posZ): {pos_og}\
\n(rotX, rotY): {rot_og}\n\
Predicted:\
\n(bx, by, bw, bh): {frame_pred}\
\n(posX, posY, posZ): {pos_pred}\
\n(rotX, rotY): {rot_pred}\
\nError\
\nPosition: {pos_error}%\
\nRotation: {rot_error}%")

plt.show()

# %% [markdown]
# # Layer output extraction

# %%
def extract_layer_data(layer):
    submodel = keras.Model(inputs = model.input, outputs = layer.output)
    submodel_output = submodel.predict(np.array(X[random_index]).reshape(1, IMG_SIZE, IMG_SIZE, 3))
    output_shape = submodel_output.shape
    
    graph_size = 10
    
    index = 0
    if (len(output_shape) != 2):
        if(output_shape[-1]>=4):
            fig, axs = plt.subplots(4, int(output_shape[-1]/4), figsize=(graph_size, graph_size))
            fig.suptitle(f"{layer.name}, [{output_shape}]")
            for col in range(0, 4):
                for row in range(0, int(output_shape[-1]/4)):
                    axs[col, row].imshow(submodel_output[0, :, :, index], cmap="Greys")
                    index += 1
                    axs[col, row].axis('off')
            
        else:
            fig, axs = plt.subplots(ncols = output_shape[-1], figsize=(graph_size, graph_size))
            for col in range(0, output_shape[-1]):
                axs[col].imshow(submodel_output[0, :, :, index], cmap="Greys")
                if(int(output_shape[-1]/2) == col):
                    axs[col].set_title(f"{layer.name}, [{output_shape}]")
                index += 1
                axs[col].axis('off')
    plt.tight_layout()

# %%
for layer in model.layers:
    extract_layer_data(layer)

# %%
from IPython.core.display import HTML
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}

</style>
""")
# Out:
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
#
# </style>

# %%
plt.rcParams.update({'font.size': 15})

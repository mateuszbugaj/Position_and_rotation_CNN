# %% [markdown]
# # Position and rotation estimation with pooling layers and RGB images
# ## Using rotations defined by RGB values

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
import cv2
import random
import math

import tensorflow as tf
tf.get_logger().setLevel('ERROR')
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow.keras.backend as K
from tensorflow.keras import Input
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, LeakyReLU

# %% [markdown]
# # Preparing data

# %%
DATADIR = "dataset_generator/images/pose5000/"
JSON_file_name = "data.txt"
IMAGES = 5_000
OG_IMG_SIZE = 800
IMG_SIZE = 150

# %%
data_json = []
for line in open(DATADIR + JSON_file_name, 'r'):
    data_json.append(json.loads(line))
    
dataset = [] # [x, y]

for img in os.listdir(DATADIR):
    if(img.endswith(".jpg")):
        img_array = cv2.imread(os.path.join(DATADIR, img))
        img_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))

        img_index = int(img.strip(".jpg"))
        for label in data_json:
            if(label['index'] == img_index):
                choosen_label = {'bx': label['bx'], 
                                 'by': label['by'], 
                                 'bw': label['bw'], 
                                 'bh': label['bh'], 
                                 'posX': label['posX'], 
                                 'posY': label['posY'], 
                                 'posZ': label['posZ'],
                                 'rx': label['rx'],
                                 'gx': label['gx'],
                                 'bxx': label['bxx'],
                                 'ry': label['ry'],
                                 'gy': label['gy'],
                                 'byy': label['byy'],
                                'rotX': label['rotX'],
                                'rotY': label['rotY']}
                
                xy = [img_array, choosen_label]
                dataset.append(xy)
                
        if(len(dataset)%500 ==0):
            print(f"{len(dataset)} images loaded")
        
        if(len(dataset) >= IMAGES):
            print("All images loaded")
            break
            
IMAGES = len(dataset)
print(f"{IMAGES} in total")
# Out:
# 500 images loaded
# 1000 images loaded
# 1500 images loaded
# 2000 images loaded
# 2500 images loaded
# 3000 images loaded
# 3500 images loaded
# 4000 images loaded
# 4500 images loaded
# 5000 images loaded
# All images loaded
# 5000 in total

# %% [markdown]
# # Creating training dataset

# %%
X = []
y = []

shuffled_indices = random.sample(range(0, IMAGES), IMAGES)

for i in shuffled_indices:
    
    pixels = dataset[i][0]
    pixels = pixels.astype('uint8')
    X.append(pixels)
    
    y_labels = [dataset[i][1]['bx'], 
                dataset[i][1]['by'], 
                dataset[i][1]['bw'], 
                dataset[i][1]['bh'], 
                dataset[i][1]['posX'], 
                dataset[i][1]['posY'], 
                dataset[i][1]['posZ'],
                dataset[i][1]['rx'],
                dataset[i][1]['gx'],
                dataset[i][1]['bxx'],
                dataset[i][1]['ry'],
                dataset[i][1]['gy'],
                dataset[i][1]['byy'],
               dataset[i][1]['rotX'],
               dataset[i][1]['rotY']]
    
    y.append(y_labels)

# Global Standardization
X = (np.array(X).reshape(IMAGES, IMG_SIZE, IMG_SIZE, 3) - np.mean(X)) / np.std(X)
    
for index, ya in enumerate(y):
    y[index] = np.array([ya[0]/100, 
                         ya[1]/100, 
                         ya[2]/100, 
                         ya[3]/100, 
                         ya[4]/10, 
                         ya[5]/10, 
                         ya[6]/10, 
                         ya[7]/255,
                         ya[8]/255,
                         ya[9]/255,
                         ya[10]/255,
                         ya[11]/255,
                         ya[12]/255,
                         ya[14]/360])
    
y = np.array(y)

print(f"X shape: {X.shape}\ny shape: {y.shape}")
# Out:
# X shape: (5000, 150, 150, 3)
# y shape: (5000, 14)

# %%
def RGBToAngle(rgb):
    angle = math.atan2(math.sqrt(3) * (rgb[1] - rgb[2]), 2 * rgb[0] - rgb[1] - rgb[2])
    if(angle < 0):
        angle += math.pi
    
    return math.degrees(angle)

# %%
random_index = random.randrange(IMAGES)
fig, axs = plt.subplots(ncols = 3, figsize = (15, 15))

axs[0].imshow(X[random_index][:, :, 0], cmap="Reds")
axs[1].imshow(X[random_index][:, :, 1], cmap="Greens")
axs[2].imshow(X[random_index][:, :, 2], cmap="Blues")

title = "Labels: \n\
(bx, by, bw, bh): {frameLabels}\n\
(posX, posY, posZ): {positionLabels}\n\
(rotY):{yDegrees} degrees\n".format(frameLabels = y[random_index][:4],
                              positionLabels = y[random_index][4:7],
                              rx = y[random_index][7],
                              gx = y[random_index][8],
                              bx =y[random_index][9],
                              ry = y[random_index][10],
                              gy = y[random_index][11],
                              by = y[random_index][12],
                              yDegrees = y[random_index][13]*360)

axs[1].set_title(title)

plt.show()

# %% [markdown]
# # Model

# %% [markdown]
# ### Custom accuracy metric

# %%
from tensorflow.math import add, subtract, multiply, divide, sqrt, atan2

def position_error_x(y_true, y_pred):
    error_sum = 0
    samples = len(y_true)
    for i in range(samples):
        error_sum += abs(y_true[i][0] - y_pred[i][0])
    return (error_sum * 10)/samples

def position_error_y(y_true, y_pred):
    error_sum = 0
    samples = len(y_true)
    for i in range(samples):
        error_sum += abs(y_true[i][1] - y_pred[i][1])
    return (error_sum * 10)/samples

def position_error_z(y_true, y_pred):
    error_sum = 0
    samples = len(y_true)
    for i in range(samples):
        error_sum += abs(y_true[i][2] - y_pred[i][2])
    return (error_sum * 10)/samples

def acc_20(y_true, y_pred):
    count = 0
    samples = len(y_true)
    for i in range(samples):
        angle_true = y_true[i] * 360
        angle_pred = y_pred[i] * 360
        
        if(abs(angle_true - angle_pred) < 20):
            count += 1
    return count / samples

def acc_15(y_true, y_pred):
    count = 0
    samples = len(y_true)
    for i in range(samples):
        angle_true = y_true[i] * 360
        angle_pred = y_pred[i] * 360
        
        if(abs(angle_true - angle_pred) < 15):
            count += 1
    return count / samples

def acc_10(y_true, y_pred):
    count = 0
    samples = len(y_true)
    for i in range(samples):
        angle_true = y_true[i] * 360
        angle_pred = y_pred[i] * 360
        
        if(abs(angle_true - angle_pred) < 10):
            count += 1
    return count / samples

def acc_5(y_true, y_pred):
    count = 0
    samples = len(y_true)
    for i in range(samples):
        angle_true = y_true[i] * 360
        angle_pred = y_pred[i] * 360
        
        if(abs(angle_true - angle_pred) < 5):
            count += 1
    return count / samples

# %%
inputs = Input(name = "Inputs",
              shape = (IMG_SIZE, IMG_SIZE, 3))

# Main Stream
positionStream = Conv2D(name = "ps_conv_0",
                   filters = 16,
                   kernel_size = 3,
                   strides = 1,
                   padding = "valid",
                   kernel_initializer=tf.keras.initializers.GlorotUniform())(inputs)

positionStream = LeakyReLU()(positionStream)

positionStream = Conv2D(name = "ps_conv_1",
                   filters = 32,
                   kernel_size = 3,
                   strides = 1,
                   padding = "valid",
                   kernel_initializer=tf.keras.initializers.GlorotUniform())(positionStream)

positionStream = LeakyReLU()(positionStream)

positionStream = MaxPooling2D(name="ps_maxpooling_1", 
                          pool_size = (2, 2), 
                          strides = 2)(positionStream)

positionStream = Conv2D(name = "ps_conv_2",
                   filters = 32,
                   kernel_size = 3,
                   strides = 1,
                   padding = "valid",
                   kernel_initializer=tf.keras.initializers.GlorotUniform())(positionStream)

positionStream = LeakyReLU()(positionStream)

positionStream = MaxPooling2D(name="ps_maxpooling_2", 
                          pool_size = (2, 2), 
                          strides = 2)(positionStream)

# ROTATION START

rotationStream = Conv2D(name = "rs_conv_1",
                   filters = 64,
                   kernel_size = 3,
                   strides = 1,
                   padding = "same",
                   kernel_initializer=tf.keras.initializers.GlorotUniform())(positionStream)

rotationStream = LeakyReLU()(rotationStream)

rotationStream = MaxPooling2D(name="rs_maxpooling_1", 
                          pool_size = (2, 2), 
                          strides = 2)(rotationStream)

rotationStream = Conv2D(name = "rs_conv_2",
                   filters = 64,
                   kernel_size = 3,
                   strides = 1,
                   padding = "same",
                   kernel_initializer=tf.keras.initializers.GlorotUniform())(rotationStream)

rotationStream = LeakyReLU()(rotationStream)

rotationStream = MaxPooling2D(name="rs_maxpooling_2", 
                          pool_size = (2, 2), 
                          strides = 2)(rotationStream)

rotationStream = Flatten()(rotationStream)

rotationStream = Dense(20, activation = "relu")(rotationStream)
rotationStream = Dense(20, activation = "relu")(rotationStream)

rotationStream = Dense(1, name = "rotationOutput")(rotationStream)

# ROTATION END

positionStream = Conv2D(name = "ps_conv_3",
                   filters = 32,
                   kernel_size = 3,
                   strides = 1,
                   padding = "valid",
                   kernel_initializer=tf.keras.initializers.GlorotUniform())(positionStream)

positionStream = LeakyReLU()(positionStream)

positionStream = MaxPooling2D(name="ps_maxpooling_3", 
                          pool_size = (2, 2), 
                          strides = 2)(positionStream)

positionStream = Conv2D(name = "ps_conv_4",
                   filters = 32,
                   kernel_size = 3,
                   strides = 1,
                   padding = "valid",
                   kernel_initializer=tf.keras.initializers.GlorotUniform())(positionStream)

positionStream = LeakyReLU()(positionStream)

positionStream = Flatten()(positionStream)

positionStream = Dense(20, activation = "relu")(positionStream)
positionStream = Dense(20, activation = "relu")(positionStream)

positionStreamOutput = Dense(3, name = "positionOutput")(positionStream)
frameStreamOutput = Dense(4, name = "frameOutput")(positionStream)

model = keras.Model(inputs,[positionStreamOutput, rotationStream, frameStreamOutput], name = "Model")

model_optimizer = tf.keras.optimizers.Adam(
    learning_rate=0.001,
    beta_1=0.95,
    amsgrad=True)

model.compile(optimizer = model_optimizer,
             loss = {"positionOutput": tf.keras.losses.MeanSquaredError(), 
                     "rotationOutput": tf.keras.losses.MeanSquaredError(), 
                     "frameOutput": tf.keras.losses.MeanSquaredError()},
              
             metrics = {"positionOutput": [position_error_x, 
                                           position_error_y, 
                                           position_error_z], 
                        "rotationOutput": [acc_20, 
                                           acc_15, 
                                           acc_10, 
                                           acc_5]},
             run_eagerly=True)

model.summary()
keras.utils.plot_model(model, "model.png", show_shapes=True)
# Out:
# Model: "Model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Inputs (InputLayer)             [(None, 150, 150, 3) 0
# __________________________________________________________________________________________________
# ps_conv_0 (Conv2D)              (None, 148, 148, 16) 448         Inputs[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 148, 148, 16) 0           ps_conv_0[0][0]
# __________________________________________________________________________________________________
# ps_conv_1 (Conv2D)              (None, 146, 146, 32) 4640        leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 146, 146, 32) 0           ps_conv_1[0][0]
# __________________________________________________________________________________________________
# ps_maxpooling_1 (MaxPooling2D)  (None, 73, 73, 32)   0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# ps_conv_2 (Conv2D)              (None, 71, 71, 32)   9248        ps_maxpooling_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 71, 71, 32)   0           ps_conv_2[0][0]
# __________________________________________________________________________________________________
# ps_maxpooling_2 (MaxPooling2D)  (None, 35, 35, 32)   0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# rs_conv_1 (Conv2D)              (None, 35, 35, 64)   18496       ps_maxpooling_2[0][0]
# __________________________________________________________________________________________________
# ps_conv_3 (Conv2D)              (None, 33, 33, 32)   9248        ps_maxpooling_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 35, 35, 64)   0           rs_conv_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 33, 33, 32)   0           ps_conv_3[0][0]
# __________________________________________________________________________________________________
# rs_maxpooling_1 (MaxPooling2D)  (None, 17, 17, 64)   0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# ps_maxpooling_3 (MaxPooling2D)  (None, 16, 16, 32)   0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# rs_conv_2 (Conv2D)              (None, 17, 17, 64)   36928       rs_maxpooling_1[0][0]
# __________________________________________________________________________________________________
# ps_conv_4 (Conv2D)              (None, 14, 14, 32)   9248        ps_maxpooling_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 17, 17, 64)   0           rs_conv_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 14, 14, 32)   0           ps_conv_4[0][0]
# __________________________________________________________________________________________________
# rs_maxpooling_2 (MaxPooling2D)  (None, 8, 8, 64)     0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 6272)         0           leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 4096)         0           rs_maxpooling_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 20)           125460      flatten_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 20)           81940       flatten[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 20)           420         dense_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 20)           420         dense[0][0]
# __________________________________________________________________________________________________
# positionOutput (Dense)          (None, 3)            63          dense_3[0][0]
# __________________________________________________________________________________________________
# rotationOutput (Dense)          (None, 1)            21          dense_1[0][0]
# __________________________________________________________________________________________________
# frameOutput (Dense)             (None, 4)            84          dense_3[0][0]
# ==================================================================================================
# Total params: 296,664
# Trainable params: 296,664
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Training

# %%
training_data_x = X[:int(IMAGES*0.9)]
training_data_y = y[:int(IMAGES*0.9)]
validation_data_x = X[int(IMAGES*0.9):IMAGES]
validation_data_y = y[int(IMAGES*0.9):IMAGES]

history = model.fit(x = training_data_x,
                    y = {"positionOutput": training_data_y[:, 4:7], "rotationOutput": training_data_y[:, 13], "frameOutput": training_data_y[:, 0:4]},
                    validation_data = (validation_data_x, {"positionOutput": validation_data_y[:, 4:7], "rotationOutput": validation_data_y[:, 13], "frameOutput": validation_data_y[:, 0:4]}),
                    batch_size = 32,
                    epochs = 20)
# Out:
# Epoch 1/20
# 141/141 [==============================] - 133s 945ms/step - loss: 5.9839 - positionOutput_loss: 2.3449 - rotationOutput_loss: 0.0948 - frameOutput_loss: 3.5442 - positionOutput_position_error_x: 6.1940 - positionOutput_position_error_y: 18.6447 - positionOutput_position_error_z: 11.6148 - rotationOutput_acc_20: 0.1154 - rotationOutput_acc_15: 0.0867 - rotationOutput_acc_10: 0.0619 - rotationOutput_acc_5: 0.0312 - val_loss: 1.3597 - val_positionOutput_loss: 0.5878 - val_rotationOutput_loss: 0.0943 - val_frameOutput_loss: 0.6776 - val_positionOutput_position_error_x: 4.0146 - val_positionOutput_position_error_y: 8.5298 - val_positionOutput_position_error_z: 4.9355 - val_rotationOutput_acc_20: 0.0977 - val_rotationOutput_acc_15: 0.0809 - val_rotationOutput_acc_10: 0.0582 - val_rotationOutput_acc_5: 0.0238
# Epoch 2/20
# 141/141 [==============================] - 141s 1s/step - loss: 0.6907 - positionOutput_loss: 0.2425 - rotationOutput_loss: 0.0804 - frameOutput_loss: 0.3678 - positionOutput_position_error_x: 3.2911 - positionOutput_position_error_y: 3.5199 - positionOutput_position_error_z: 4.3537 - rotationOutput_acc_20: 0.0895 - rotationOutput_acc_15: 0.0686 - rotationOutput_acc_10: 0.0460 - rotationOutput_acc_5: 0.0219 - val_loss: 0.4575 - val_positionOutput_loss: 0.1711 - val_rotationOutput_loss: 0.0744 - val_frameOutput_loss: 0.2120 - val_positionOutput_position_error_x: 2.9060 - val_positionOutput_position_error_y: 2.3969 - val_positionOutput_position_error_z: 4.2653 - val_rotationOutput_acc_20: 0.0520 - val_rotationOutput_acc_15: 0.0422 - val_rotationOutput_acc_10: 0.0266 - val_rotationOutput_acc_5: 0.0148
# Epoch 3/20
# 141/141 [==============================] - 130s 921ms/step - loss: 0.3613 - positionOutput_loss: 0.1386 - rotationOutput_loss: 0.0549 - frameOutput_loss: 0.1677 - positionOutput_position_error_x: 2.5366 - positionOutput_position_error_y: 2.4819 - positionOutput_position_error_z: 3.6510 - rotationOutput_acc_20: 0.1335 - rotationOutput_acc_15: 0.1007 - rotationOutput_acc_10: 0.0685 - rotationOutput_acc_5: 0.0306 - val_loss: 0.3249 - val_positionOutput_loss: 0.1361 - val_rotationOutput_loss: 0.0352 - val_frameOutput_loss: 0.1536 - val_positionOutput_position_error_x: 2.4073 - val_positionOutput_position_error_y: 2.4537 - val_positionOutput_position_error_z: 3.6335 - val_rotationOutput_acc_20: 0.2930 - val_rotationOutput_acc_15: 0.2352 - val_rotationOutput_acc_10: 0.1559 - val_rotationOutput_acc_5: 0.0777
# Epoch 4/20
# 141/141 [==============================] - 130s 922ms/step - loss: 0.2555 - positionOutput_loss: 0.1065 - rotationOutput_loss: 0.0227 - frameOutput_loss: 0.1264 - positionOutput_position_error_x: 2.1495 - positionOutput_position_error_y: 2.3494 - positionOutput_position_error_z: 3.1302 - rotationOutput_acc_20: 0.3528 - rotationOutput_acc_15: 0.2740 - rotationOutput_acc_10: 0.1844 - rotationOutput_acc_5: 0.0959 - val_loss: 0.2551 - val_positionOutput_loss: 0.0985 - val_rotationOutput_loss: 0.0292 - val_frameOutput_loss: 0.1274 - val_positionOutput_position_error_x: 1.9553 - val_positionOutput_position_error_y: 2.1717 - val_positionOutput_position_error_z: 3.1471 - val_rotationOutput_acc_20: 0.2988 - val_rotationOutput_acc_15: 0.2215 - val_rotationOutput_acc_10: 0.1312 - val_rotationOutput_acc_5: 0.0707
# Epoch 5/20
# 141/141 [==============================] - 131s 926ms/step - loss: 0.2046 - positionOutput_loss: 0.0847 - rotationOutput_loss: 0.0141 - frameOutput_loss: 0.1058 - positionOutput_position_error_x: 1.8221 - positionOutput_position_error_y: 2.2278 - positionOutput_position_error_z: 2.7353 - rotationOutput_acc_20: 0.4472 - rotationOutput_acc_15: 0.3465 - rotationOutput_acc_10: 0.2341 - rotationOutput_acc_5: 0.1211 - val_loss: 0.1959 - val_positionOutput_loss: 0.0769 - val_rotationOutput_loss: 0.0196 - val_frameOutput_loss: 0.0994 - val_positionOutput_position_error_x: 1.6270 - val_positionOutput_position_error_y: 2.1918 - val_positionOutput_position_error_z: 2.5842 - val_rotationOutput_acc_20: 0.4707 - val_rotationOutput_acc_15: 0.3734 - val_rotationOutput_acc_10: 0.2422 - val_rotationOutput_acc_5: 0.1129
# Epoch 6/20
# 141/141 [==============================] - 131s 931ms/step - loss: 0.1610 - positionOutput_loss: 0.0650 - rotationOutput_loss: 0.0099 - frameOutput_loss: 0.0861 - positionOutput_position_error_x: 1.5357 - positionOutput_position_error_y: 2.0881 - positionOutput_position_error_z: 2.2959 - rotationOutput_acc_20: 0.5305 - rotationOutput_acc_15: 0.4230 - rotationOutput_acc_10: 0.2913 - rotationOutput_acc_5: 0.1515 - val_loss: 0.1611 - val_positionOutput_loss: 0.0610 - val_rotationOutput_loss: 0.0180 - val_frameOutput_loss: 0.0821 - val_positionOutput_position_error_x: 1.5662 - val_positionOutput_position_error_y: 1.9969 - val_positionOutput_position_error_z: 2.2073 - val_rotationOutput_acc_20: 0.4855 - val_rotationOutput_acc_15: 0.3805 - val_rotationOutput_acc_10: 0.2711 - val_rotationOutput_acc_5: 0.1586
# Epoch 7/20
# 141/141 [==============================] - 131s 931ms/step - loss: 0.1325 - positionOutput_loss: 0.0554 - rotationOutput_loss: 0.0069 - frameOutput_loss: 0.0702 - positionOutput_position_error_x: 1.3520 - positionOutput_position_error_y: 1.9826 - positionOutput_position_error_z: 2.1254 - rotationOutput_acc_20: 0.6116 - rotationOutput_acc_15: 0.4938 - rotationOutput_acc_10: 0.3468 - rotationOutput_acc_5: 0.1828 - val_loss: 0.1328 - val_positionOutput_loss: 0.0534 - val_rotationOutput_loss: 0.0158 - val_frameOutput_loss: 0.0636 - val_positionOutput_position_error_x: 1.3078 - val_positionOutput_position_error_y: 2.0076 - val_positionOutput_position_error_z: 2.0762 - val_rotationOutput_acc_20: 0.5437 - val_rotationOutput_acc_15: 0.4234 - val_rotationOutput_acc_10: 0.3059 - val_rotationOutput_acc_5: 0.1453
# Epoch 8/20
# 141/141 [==============================] - 132s 934ms/step - loss: 0.1093 - positionOutput_loss: 0.0451 - rotationOutput_loss: 0.0051 - frameOutput_loss: 0.0591 - positionOutput_position_error_x: 1.2703 - positionOutput_position_error_y: 1.8242 - positionOutput_position_error_z: 1.8401 - rotationOutput_acc_20: 0.6630 - rotationOutput_acc_15: 0.5363 - rotationOutput_acc_10: 0.3824 - rotationOutput_acc_5: 0.1934 - val_loss: 0.1117 - val_positionOutput_loss: 0.0437 - val_rotationOutput_loss: 0.0154 - val_frameOutput_loss: 0.0526 - val_positionOutput_position_error_x: 1.2970 - val_positionOutput_position_error_y: 1.6814 - val_positionOutput_position_error_z: 1.8671 - val_rotationOutput_acc_20: 0.5773 - val_rotationOutput_acc_15: 0.4621 - val_rotationOutput_acc_10: 0.3367 - val_rotationOutput_acc_5: 0.2023
# Epoch 9/20
# 141/141 [==============================] - 133s 941ms/step - loss: 0.0876 - positionOutput_loss: 0.0365 - rotationOutput_loss: 0.0042 - frameOutput_loss: 0.0469 - positionOutput_position_error_x: 1.1250 - positionOutput_position_error_y: 1.5445 - positionOutput_position_error_z: 1.7257 - rotationOutput_acc_20: 0.6867 - rotationOutput_acc_15: 0.5585 - rotationOutput_acc_10: 0.3873 - rotationOutput_acc_5: 0.1999 - val_loss: 0.0962 - val_positionOutput_loss: 0.0353 - val_rotationOutput_loss: 0.0156 - val_frameOutput_loss: 0.0454 - val_positionOutput_position_error_x: 1.0951 - val_positionOutput_position_error_y: 1.4942 - val_positionOutput_position_error_z: 1.7140 - val_rotationOutput_acc_20: 0.5973 - val_rotationOutput_acc_15: 0.4617 - val_rotationOutput_acc_10: 0.3359 - val_rotationOutput_acc_5: 0.1980
# Epoch 10/20
# 141/141 [==============================] - 133s 940ms/step - loss: 0.0759 - positionOutput_loss: 0.0307 - rotationOutput_loss: 0.0038 - frameOutput_loss: 0.0414 - positionOutput_position_error_x: 1.0782 - positionOutput_position_error_y: 1.3677 - positionOutput_position_error_z: 1.5885 - rotationOutput_acc_20: 0.6940 - rotationOutput_acc_15: 0.5794 - rotationOutput_acc_10: 0.4097 - rotationOutput_acc_5: 0.2140 - val_loss: 0.0881 - val_positionOutput_loss: 0.0307 - val_rotationOutput_loss: 0.0155 - val_frameOutput_loss: 0.0419 - val_positionOutput_position_error_x: 1.1482 - val_positionOutput_position_error_y: 1.2856 - val_positionOutput_position_error_z: 1.6442 - val_rotationOutput_acc_20: 0.5578 - val_rotationOutput_acc_15: 0.4344 - val_rotationOutput_acc_10: 0.3145 - val_rotationOutput_acc_5: 0.1762
# Epoch 11/20
# 141/141 [==============================] - 132s 936ms/step - loss: 0.0683 - positionOutput_loss: 0.0282 - rotationOutput_loss: 0.0025 - frameOutput_loss: 0.0376 - positionOutput_position_error_x: 1.0337 - positionOutput_position_error_y: 1.2680 - positionOutput_position_error_z: 1.5541 - rotationOutput_acc_20: 0.7893 - rotationOutput_acc_15: 0.6742 - rotationOutput_acc_10: 0.4947 - rotationOutput_acc_5: 0.2621 - val_loss: 0.0799 - val_positionOutput_loss: 0.0295 - val_rotationOutput_loss: 0.0132 - val_frameOutput_loss: 0.0373 - val_positionOutput_position_error_x: 1.0865 - val_positionOutput_position_error_y: 1.2655 - val_positionOutput_position_error_z: 1.6149 - val_rotationOutput_acc_20: 0.6094 - val_rotationOutput_acc_15: 0.4957 - val_rotationOutput_acc_10: 0.3535 - val_rotationOutput_acc_5: 0.1762
# Epoch 12/20
# 141/141 [==============================] - 133s 944ms/step - loss: 0.0622 - positionOutput_loss: 0.0255 - rotationOutput_loss: 0.0019 - frameOutput_loss: 0.0347 - positionOutput_position_error_x: 0.9700 - positionOutput_position_error_y: 1.1874 - positionOutput_position_error_z: 1.5049 - rotationOutput_acc_20: 0.8305 - rotationOutput_acc_15: 0.7125 - rotationOutput_acc_10: 0.5323 - rotationOutput_acc_5: 0.2902 - val_loss: 0.0732 - val_positionOutput_loss: 0.0263 - val_rotationOutput_loss: 0.0131 - val_frameOutput_loss: 0.0339 - val_positionOutput_position_error_x: 0.9851 - val_positionOutput_position_error_y: 1.1684 - val_positionOutput_position_error_z: 1.5491 - val_rotationOutput_acc_20: 0.6180 - val_rotationOutput_acc_15: 0.5074 - val_rotationOutput_acc_10: 0.3730 - val_rotationOutput_acc_5: 0.1840
# Epoch 13/20
# 141/141 [==============================] - 131s 930ms/step - loss: 0.0540 - positionOutput_loss: 0.0221 - rotationOutput_loss: 0.0014 - frameOutput_loss: 0.0305 - positionOutput_position_error_x: 0.9209 - positionOutput_position_error_y: 1.0994 - positionOutput_position_error_z: 1.3911 - rotationOutput_acc_20: 0.8845 - rotationOutput_acc_15: 0.7712 - rotationOutput_acc_10: 0.5911 - rotationOutput_acc_5: 0.3304 - val_loss: 0.0708 - val_positionOutput_loss: 0.0238 - val_rotationOutput_loss: 0.0131 - val_frameOutput_loss: 0.0339 - val_positionOutput_position_error_x: 0.9689 - val_positionOutput_position_error_y: 1.1795 - val_positionOutput_position_error_z: 1.4103 - val_rotationOutput_acc_20: 0.6129 - val_rotationOutput_acc_15: 0.5195 - val_rotationOutput_acc_10: 0.3766 - val_rotationOutput_acc_5: 0.2277
# Epoch 14/20
# 141/141 [==============================] - 131s 930ms/step - loss: 0.0490 - positionOutput_loss: 0.0199 - rotationOutput_loss: 0.0012 - frameOutput_loss: 0.0278 - positionOutput_position_error_x: 0.8871 - positionOutput_position_error_y: 1.0693 - positionOutput_position_error_z: 1.2750 - rotationOutput_acc_20: 0.9017 - rotationOutput_acc_15: 0.7988 - rotationOutput_acc_10: 0.6293 - rotationOutput_acc_5: 0.3617 - val_loss: 0.0629 - val_positionOutput_loss: 0.0225 - val_rotationOutput_loss: 0.0126 - val_frameOutput_loss: 0.0278 - val_positionOutput_position_error_x: 0.8798 - val_positionOutput_position_error_y: 1.1244 - val_positionOutput_position_error_z: 1.3800 - val_rotationOutput_acc_20: 0.6234 - val_rotationOutput_acc_15: 0.5023 - val_rotationOutput_acc_10: 0.3574 - val_rotationOutput_acc_5: 0.1961
# Epoch 15/20
# 141/141 [==============================] - 132s 937ms/step - loss: 0.0464 - positionOutput_loss: 0.0190 - rotationOutput_loss: 9.5078e-04 - frameOutput_loss: 0.0264 - positionOutput_position_error_x: 0.8829 - positionOutput_position_error_y: 1.0294 - positionOutput_position_error_z: 1.2376 - rotationOutput_acc_20: 0.9333 - rotationOutput_acc_15: 0.8496 - rotationOutput_acc_10: 0.6700 - rotationOutput_acc_5: 0.3885 - val_loss: 0.0621 - val_positionOutput_loss: 0.0215 - val_rotationOutput_loss: 0.0128 - val_frameOutput_loss: 0.0278 - val_positionOutput_position_error_x: 0.9203 - val_positionOutput_position_error_y: 1.0708 - val_positionOutput_position_error_z: 1.3376 - val_rotationOutput_acc_20: 0.6715 - val_rotationOutput_acc_15: 0.5410 - val_rotationOutput_acc_10: 0.3762 - val_rotationOutput_acc_5: 0.2117
# Epoch 16/20
# 141/141 [==============================] - 132s 937ms/step - loss: 0.0420 - positionOutput_loss: 0.0173 - rotationOutput_loss: 6.4383e-04 - frameOutput_loss: 0.0240 - positionOutput_position_error_x: 0.8346 - positionOutput_position_error_y: 0.9892 - positionOutput_position_error_z: 1.1848 - rotationOutput_acc_20: 0.9711 - rotationOutput_acc_15: 0.9102 - rotationOutput_acc_10: 0.7563 - rotationOutput_acc_5: 0.4531 - val_loss: 0.0597 - val_positionOutput_loss: 0.0211 - val_rotationOutput_loss: 0.0120 - val_frameOutput_loss: 0.0266 - val_positionOutput_position_error_x: 0.9415 - val_positionOutput_position_error_y: 1.0422 - val_positionOutput_position_error_z: 1.3332 - val_rotationOutput_acc_20: 0.6707 - val_rotationOutput_acc_15: 0.5383 - val_rotationOutput_acc_10: 0.3969 - val_rotationOutput_acc_5: 0.2336
# Epoch 17/20
# 141/141 [==============================] - 133s 941ms/step - loss: 0.0398 - positionOutput_loss: 0.0166 - rotationOutput_loss: 6.2673e-04 - frameOutput_loss: 0.0226 - positionOutput_position_error_x: 0.8245 - positionOutput_position_error_y: 0.9677 - positionOutput_position_error_z: 1.1564 - rotationOutput_acc_20: 0.9730 - rotationOutput_acc_15: 0.9137 - rotationOutput_acc_10: 0.7606 - rotationOutput_acc_5: 0.4527 - val_loss: 0.0603 - val_positionOutput_loss: 0.0221 - val_rotationOutput_loss: 0.0127 - val_frameOutput_loss: 0.0255 - val_positionOutput_position_error_x: 1.0189 - val_positionOutput_position_error_y: 1.0880 - val_positionOutput_position_error_z: 1.3197 - val_rotationOutput_acc_20: 0.6734 - val_rotationOutput_acc_15: 0.5848 - val_rotationOutput_acc_10: 0.4309 - val_rotationOutput_acc_5: 0.2359
# Epoch 18/20
# 141/141 [==============================] - 133s 943ms/step - loss: 0.0373 - positionOutput_loss: 0.0156 - rotationOutput_loss: 5.7729e-04 - frameOutput_loss: 0.0211 - positionOutput_position_error_x: 0.7773 - positionOutput_position_error_y: 0.9616 - positionOutput_position_error_z: 1.1157 - rotationOutput_acc_20: 0.9788 - rotationOutput_acc_15: 0.9257 - rotationOutput_acc_10: 0.7817 - rotationOutput_acc_5: 0.4611 - val_loss: 0.0541 - val_positionOutput_loss: 0.0192 - val_rotationOutput_loss: 0.0129 - val_frameOutput_loss: 0.0220 - val_positionOutput_position_error_x: 0.8178 - val_positionOutput_position_error_y: 1.0197 - val_positionOutput_position_error_z: 1.2994 - val_rotationOutput_acc_20: 0.6801 - val_rotationOutput_acc_15: 0.5363 - val_rotationOutput_acc_10: 0.4023 - val_rotationOutput_acc_5: 0.2418
# Epoch 19/20
# 141/141 [==============================] - 132s 936ms/step - loss: 0.0345 - positionOutput_loss: 0.0145 - rotationOutput_loss: 4.1849e-04 - frameOutput_loss: 0.0195 - positionOutput_position_error_x: 0.7479 - positionOutput_position_error_y: 0.9165 - positionOutput_position_error_z: 1.0902 - rotationOutput_acc_20: 0.9897 - rotationOutput_acc_15: 0.9574 - rotationOutput_acc_10: 0.8364 - rotationOutput_acc_5: 0.5272 - val_loss: 0.0561 - val_positionOutput_loss: 0.0200 - val_rotationOutput_loss: 0.0122 - val_frameOutput_loss: 0.0239 - val_positionOutput_position_error_x: 0.9992 - val_positionOutput_position_error_y: 1.0143 - val_positionOutput_position_error_z: 1.2234 - val_rotationOutput_acc_20: 0.6695 - val_rotationOutput_acc_15: 0.5578 - val_rotationOutput_acc_10: 0.4113 - val_rotationOutput_acc_5: 0.2145
# Epoch 20/20
# 141/141 [==============================] - 132s 934ms/step - loss: 0.0381 - positionOutput_loss: 0.0163 - rotationOutput_loss: 4.2449e-04 - frameOutput_loss: 0.0214 - positionOutput_position_error_x: 0.8262 - positionOutput_position_error_y: 0.9762 - positionOutput_position_error_z: 1.1495 - rotationOutput_acc_20: 0.9896 - rotationOutput_acc_15: 0.9577 - rotationOutput_acc_10: 0.8414 - rotationOutput_acc_5: 0.5257 - val_loss: 0.0617 - val_positionOutput_loss: 0.0237 - val_rotationOutput_loss: 0.0122 - val_frameOutput_loss: 0.0258 - val_positionOutput_position_error_x: 0.9053 - val_positionOutput_position_error_y: 1.0543 - val_positionOutput_position_error_z: 1.5308 - val_rotationOutput_acc_20: 0.6641 - val_rotationOutput_acc_15: 0.5496 - val_rotationOutput_acc_10: 0.4094 - val_rotationOutput_acc_5: 0.2555

# %%
for k in history.history.keys():
    print(k)

fig, axs = plt.subplots(ncols = 1, nrows = 8, figsize=(10,30))

axs[0].plot(history.history['loss'], label = "training")
axs[0].plot(history.history['val_loss'], label = "validation")
axs[0].set_ylabel('loss')
axs[0].set_xlabel('epoch')
axs[0].legend(loc='upper right')
axs[0].set_title("Total loss")

axs[1].plot(history.history['positionOutput_loss'], label = "training")
axs[1].plot(history.history['val_positionOutput_loss'], label = "validation")
axs[1].set_xlabel('epoch')
axs[1].legend(loc='upper right')
axs[1].set_title("Position loss")

axs[2].plot(history.history['positionOutput_position_error_x'], label = "X Axis")
axs[2].plot(history.history['positionOutput_position_error_y'], label = "Y Axis")
axs[2].plot(history.history['positionOutput_position_error_z'], label = "Z Axis")
axs[2].set_ylabel('Mean absolute error')
axs[2].set_xlabel('epoch')
axs[2].legend(loc='upper right')
axs[2].set_title("Position error training")

axs[3].plot(history.history['val_positionOutput_position_error_x'], label = "X Axis")
axs[3].plot(history.history['val_positionOutput_position_error_y'], label = "Y Axis")
axs[3].plot(history.history['val_positionOutput_position_error_z'], label = "Z Axis")
axs[3].set_ylabel('Mean absolute error')
axs[3].set_xlabel('epoch')
axs[3].legend(loc='upper right')
axs[3].set_title("Position error validation")

axs[4].plot(history.history['rotationOutput_loss'], label = "training")
axs[4].plot(history.history['val_rotationOutput_loss'], label = "validation")
axs[4].set_xlabel('epoch')
axs[4].legend(loc='upper right')
axs[4].set_title("Rotation loss")

axs[5].plot(history.history['rotationOutput_acc_20'], label = "training")
axs[5].plot(history.history['val_rotationOutput_acc_20'], label = "validation")
axs[5].set_xlabel('epoch')
axs[5].legend(loc='lower right')
axs[5].set_title("ACC_20")

axs[6].plot(history.history['rotationOutput_acc_15'], label = "training")
axs[6].plot(history.history['val_rotationOutput_acc_15'], label = "validation")
axs[6].set_xlabel('epoch')
axs[6].legend(loc='lower right')
axs[6].set_title("ACC_15")

axs[7].plot(history.history['rotationOutput_acc_5'], label = "training")
axs[7].plot(history.history['val_rotationOutput_acc_5'], label = "validation")
axs[7].set_xlabel('epoch')
axs[7].legend(loc='lower right')
axs[7].set_title("ACC_5")

plt.subplots_adjust(hspace=0.5)
plt.show()
# Out:
# loss
# positionOutput_loss
# rotationOutput_loss
# frameOutput_loss
# positionOutput_position_error_x
# positionOutput_position_error_y
# positionOutput_position_error_z
# rotationOutput_acc_20
# rotationOutput_acc_15
# rotationOutput_acc_10
# rotationOutput_acc_5
# val_loss
# val_positionOutput_loss
# val_rotationOutput_loss
# val_frameOutput_loss
# val_positionOutput_position_error_x
# val_positionOutput_position_error_y
# val_positionOutput_position_error_z
# val_rotationOutput_acc_20
# val_rotationOutput_acc_15
# val_rotationOutput_acc_10
# val_rotationOutput_acc_5

# %% [markdown]
# # Results
# ### On validation data

# %%
# random_index = random.randrange(len(training_data))
# Images from trainig set
# random_index = random.randrange(IMAGES*0.8)

# Images from validation set
random_index = random.randrange(IMAGES*0.8 ,IMAGES)

prediction = model.predict(X[random_index].reshape(1, IMG_SIZE, IMG_SIZE, 3))

fig, axs = plt.subplots(ncols = 3, figsize = (15, 15))

axs[0].imshow(X[random_index][:, :, 0], cmap="Reds")
axs[1].imshow(X[random_index][:, :, 1], cmap="Greens")
axs[2].imshow(X[random_index][:, :, 2], cmap="Blues")

frame_og = y[random_index][:4]*100
pos_og = y[random_index][4:7]*10
rot_og = [int(RGBToAngle(y[random_index][10:13]))]

frame_pred = [int(p*100) for p in prediction[2][0]]
pos_pred = [int(p*10) for p in prediction[0][0]]
rot_pred = [int(RGBToAngle(prediction[1][0][0:3]))]

pos_error = int(sum((abs(pos_pred-pos_og)/30)*100)/3)
rot_error = int(abs((rot_pred[0]-rot_og[0])/360)*100)

axs[1].set_title(f"Labels:\
\n(bx, by, bw, bh): {frame_og}\
\n(posX, posY, posZ): {pos_og}\
\n(rotX, rotY): {rot_og}\n\
Predicted:\
\n(bx, by, bw, bh): {frame_pred}\
\n(posX, posY, posZ): {pos_pred}\
\n(rotY): {rot_pred}\
\nError\
\nPosition: {pos_error}%\
\nRotation: {rot_error}%")

plt.show()

# %% [markdown]
# ### On training data

# %%
random_index = random.randrange(IMAGES)

prediction = model.predict(X[random_index].reshape(1, IMG_SIZE, IMG_SIZE, 3))

fig, axs = plt.subplots(ncols = 3, figsize = (15, 15))

axs[0].imshow(X[random_index][:, :, 0], cmap="Reds")
axs[1].imshow(X[random_index][:, :, 1], cmap="Greens")
axs[2].imshow(X[random_index][:, :, 2], cmap="Blues")

frame_og = y[random_index][:4]*100
pos_og = y[random_index][4:7]*10
rot_og = [int(RGBToAngle(y[random_index][7:10])), int(RGBToAngle(y[random_index][10:13]))]

frame_pred = [int(p*100) for p in prediction[2][0]]
pos_pred = [int(p*10) for p in prediction[0][0]]
rot_pred = [int(RGBToAngle(prediction[1][0][0:3])), int(RGBToAngle(prediction[1][0][3:7]))]

pos_error = int(sum((abs(pos_pred-pos_og)/30)*100))
rot_error = int(sum([abs((rot_pred[0]-rot_og[0])/360), abs(rot_pred[1]-rot_og[1])/360])*100)

axs[1].set_title(f"Labels:\
\n(bx, by, bw, bh): {frame_og}\
\n(posX, posY, posZ): {pos_og}\
\n(rotX, rotY): {rot_og}\n\
Predicted:\
\n(bx, by, bw, bh): {frame_pred}\
\n(posX, posY, posZ): {pos_pred}\
\n(rotX, rotY): {rot_pred}\
\nError\
\nPosition: {pos_error}%\
\nRotation: {rot_error}%")

plt.show()

# %% [markdown]
# # Layer output extraction

# %%
def extract_layer_data(layer):
    submodel = keras.Model(inputs = model.input, outputs = layer.output)
    submodel_output = submodel.predict(np.array(X[random_index]).reshape(1, IMG_SIZE, IMG_SIZE, 3))
    output_shape = submodel_output.shape
    
    graph_size = 10
    
    index = 0
    if (len(output_shape) != 2):
        if(output_shape[-1]>=4):
            fig, axs = plt.subplots(4, int(output_shape[-1]/4), figsize=(graph_size, graph_size))
            fig.suptitle(f"{layer.name}, [{output_shape}]")
            for col in range(0, 4):
                for row in range(0, int(output_shape[-1]/4)):
                    axs[col, row].imshow(submodel_output[0, :, :, index], cmap="Greys")
                    index += 1
                    axs[col, row].axis('off')
            
        else:
            fig, axs = plt.subplots(ncols = output_shape[-1], figsize=(graph_size, graph_size))
            for col in range(0, output_shape[-1]):
                axs[col].imshow(submodel_output[0, :, :, index], cmap="Greys")
                if(int(output_shape[-1]/2) == col):
                    axs[col].set_title(f"{layer.name}, [{output_shape}]")
                index += 1
                axs[col].axis('off')
    plt.tight_layout()
    
# for layer in model.layers:
#     extract_layer_data(layer)

# %%
from IPython.core.display import HTML
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}

</style>
""")
# Out:
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
#
# </style>

# %%
plt.rcParams.update({'font.size': 15})
